# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahmed-Sohail2000/Solar-Eye-Project/blob/main/Solar_Eye_%F0%9F%8C%9E%F0%9F%91%80_Solar_Image_Classification_Project_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Solar Eye 🌞👀

# %% [markdown]
# ## Project Scope and Objectives 🎯
#
# A multi-class classification problem to classify the faults of solar pv modules using UAV drones and deep learning model.
#
# This project aims to develop an AI-driven system that utilizes drone technology to capture images or videos of solar photovoltaic (PV) modules for the purpose of predicting and classifying faults. The integration of AI with drone imagery can enhance the efficiency and effectiveness of solar panel inspections, leading to improved maintenance and operational reliability.
#
# The solareye project falls under the Computer Vision category in Deep Learning and will implement CNN model architecture.
#
# The study employs computer vision techniques to detect various errors in solar cell manufacture usingthe YOLOv8 architecture; this new technique can address the drawbacks of conventional detection techniques,including their rigidity, slowness, and reduced accuracy. The experimental findings prove that the proposed approach can effectively and accurately detect numerous defaults that are present on solar cell surfaces, short-circuit, fracture, and horizontal dissolution.
#
# The objectives of the project would be:
#
# **Automate Inspections:** Replace manual inspections with drone-based automated systems, reducing labor costs and time.
#
# **Enhance Accuracy:** Achieve >90% accuracy in fault detection and classification using AI models.
#
# **Increase Efficiency:** Reduce inspection time by 50% compared to traditional methods.
#
# **Provide Actionable Insights:** Deliver detailed reports to maintenance teams for timely repairs.
#
# The project is referenced by a journal article called [CNN-based automatic detection of photovoltaic solar module
# anomalies in infrared images: a comparative study]
# ](https://www.researchgate.net/publication/383036389_CNN-based_automatic_detection_of_photovoltaic_solar_module_anomalies_in_infrared_images_a_comparative_study)
#
#
# ## Key Project Components 🛠️
#
# A. Drone Setup
#
# Drone Selection:
# Model: DJI Matrice 300 RTK or similar industrial-grade drones.
# Payload Capacity: Must support thermal and visible spectrum cameras.
# Flight Time: Minimum 30 minutes for large solar farms.
# Camera Specifications:
# Thermal Camera: FLIR Vue Pro or similar, with a resolution of 640x512 pixels and a thermal sensitivity of <50mK.
# Visible Spectrum Camera: 20MP or higher resolution for detailed visual inspection.
# Flight Planning:
# Software: Use DJI Pilot or Pix4D for automated flight planning.
# Parameters: Altitude of 10-20 meters, speed of 2-3 m/s, and 70% image overlap for comprehensive coverage.
#
# B. Data Collection
#
# Image/Video Capture:
# Frequency: Weekly or bi-weekly inspections, depending on the size of the solar farm.
# Conditions: Capture images during clear weather and at consistent times (e.g., midday) to minimize variations.
# Annotation:
# Tools: Use LabelImg or CVAT for annotating images with bounding boxes and labels (e.g., cracks, hot spots, soiling).
# Dataset Size: Aim for at least 10,000 annotated images for robust model training.
#
# C. AI Model Development
#
# Model Selection:
# YOLOv8: For real-time object detection and classification.
# EfficientNet-B4: For high-accuracy image classification.
# Transfer Learning: Use pre-trained models on ImageNet and fine-tune them on your dataset.
# Data Preprocessing:
# Resizing: Resize images to 416x416 pixels for YOLO or 224x224 pixels for EfficientNet.
# Augmentation: Apply techniques like rotation, flipping, and brightness adjustment to increase dataset diversity.
# Normalization: Normalize pixel values to [0, 1] for better model convergence.
# Training:
# Framework: TensorFlow or PyTorch.
# Hyperparameters: Learning rate of 0.001, batch size of 32, and 50-100 epochs.
# Metrics: Monitor accuracy, precision, recall, and F1 score during training.
#
# D. Integration and Deployment
#
# Real-Time Processing:
# Edge Computing: Use NVIDIA Jetson Xavier or similar hardware for onboard processing.
# Cloud Integration: Store and process data in the cloud (e.g., AWS or Google Cloud) for scalability.
# User Interface:
# Dashboard: Develop a web-based dashboard using React.js or Angular for real-time monitoring.
# Mobile App: Create an app using Flutter or React Native for field technicians.
# Alerts and Reporting:
# Notifications: Use SMS or email alerts for detected faults.
# Reports: Generate PDF reports with fault locations, classifications, and recommended actions.
#
# ## Project Approach 🪜
#
# Step-by-Step Approach
#
# Define Requirements:
# Identify the size of the solar farm, types of faults to detect, and user needs.
#
# Select Technology:
# Choose drones, cameras, and AI frameworks based on project requirements.
#
# Data Collection:
# Capture and annotate images/videos of solar panels.
#
# Model Development:
# Preprocess data, train the AI model, and evaluate performance.
#
# Integration:
# Integrate the AI model with the drone system and develop the user interface.
#
# Testing:
# Conduct field tests to validate the system’s performance.
#
# Deployment:
# Deploy the system for real-world use and train end-users.
#
# Monitoring and Maintenance:
# Continuously monitor the system and update the model as needed.
#
#
# ## Project Applications 🌏
#
# 1) Solar Panel Maintenance System:
#
#   * Develop a system that automatically assesses the condition of solar panels, providing insights into whether they are clean, damaged, dirty, etc.
#   * Implement a notification system to alert maintenance personnel when issues are detected.
#
# 2) Energy Production Optimization:
#
#   * Use the classification results to optimize the cleaning schedule for solar panels, ensuring they operate at peak efficiency.
#   * Implement an intelligent system that recommends optimal cleaning frequencies based on historical data.
#
# 3) Automated Inspection Drones:
#
#   * Integrate the image classification model with drones equipped with cameras for automated aerial inspections of large solar farms.
#   * Enable the drones to identify and document areas that require attention.
#
# 4) Remote Monitoring Dashboard:
#
#   * Develop a web-based dashboard that allows users to remotely monitor the status of solar panels in real-time.
#   * Provide visualization tools and historical data to track the performance of individual panels or entire solar arrays.
#
# 5) Predictive Maintenance:
#
#   * Implement predictive maintenance based on the classification results and historical data.
#   * Use machine learning algorithms to predict potential issues before they occur, allowing for proactive maintenance.
#
# 6) Performance Analytics:
#
#   * Provide detailed analytics on the performance of solar panels over time.
#   * Include metrics such as energy production, efficiency, and degradation rates.
#
# 7) Integration with Smart Grids:
#
#   * Explore integration possibilities with smart grid systems to optimize energy distribution based on the health of individual solar panels.
#
# 8) Educational Tools:
#
#   * Develop educational tools or resources that explain the importance of solar panel maintenance and how the image classification system works.
#
# 9) Research Collaboration:
#
#   * Collaborate with research institutions or environmental organizations to contribute data for broader research on the health and performance of solar energy systems
#
# ## Project Resources 📚
#
#   Resources Needed
#
#   Hardware:
#   Drones: DJI Matrice 300 RTK (2-3 units).
#   Cameras: FLIR Vue Pro (thermal) and Sony Alpha (visible spectrum).
#   Edge Computing: NVIDIA Jetson Xavier for onboard processing.
#
#   Software:
#   AI Frameworks: TensorFlow, PyTorch, or YOLOv8.
#   Annotation Tools: LabelImg or CVAT.
#   UI Development: React.js for the dashboard and Flutter for the mobile app.
#
#   Human Resources:
#   Data Scientists: For model development and training.
#   Drone Operators: For flight planning and execution.
#   Software Developers: For UI and system integration.
#
#   Additional Resources:
#
#   * Project Dataset - https://github.com/RaptorMaps/InfraredSolarModules
#   * TensorFlow - https://www.tensorflow.org/
#   * YOLOV8 Model - https://github.com/ultralytics/ultralytics
#   * Similar Computer Vision Problem - https://dev.mrdbourke.com/tensorflow-deep-learning/03_convolutional_neural_networks_in_tensorflow/
#   * Convolutional Neural Network - https://towardsdatascience.com/convolutional-neural-networks-explained-9cc5188c4939
#   * Basic Explanation of CNN - https://www.upgrad.com/blog/basic-cnn-architecture/
#   * Solar Cell Image Classification Steps - https://umairrafiq.medium.com/solar-cells-image-classification-using-dnn-deep-neural-networks-10479ed02c16
#   * Load and preprocess input images - https://www.tensorflow.org/tutorials/load_data/images
#
# **Journal Articles:**
#
#   1) Automatic detection of solar cell surface defects in electroluminescence images based on YOLOv8 algorithm - https://www.researchgate.net/publication/376124810_Automatic_detection_of_solar_cell_surface_defects_in_electroluminescence_images_based_on_YOLOv8_algorithm
#
#  2) Image based surface damage detection of renewable energy installations using a unified deep learning approach - https://www.sciencedirect.com/science/article/pii/S2352484721005102?ref=pdf_download&fr=RR-2&rr=8802fa115cdb126e

# %% [markdown]
# ## 1.0 Getting The Project Data

# %% [markdown]
# The dataset consists of 20,000 infrared images that are 24 by 40 pixels each. There are 12 defined classes of solar modules presented in this paper with 11 classes of different anomalies and the remaining class being No-Anomaly (i.e. the null case).
#
# * Cell	1,877	Hot spot occurring with square geometry in single cell.
#
# * Cell-Multi	1,288	Hot spots occurring with square geometry in multiple cells.
#
# * Cracking	941	Module anomaly caused by cracking on module surface.
#
# * Hot-Spot	251	Hot spot on a thin film module.
#
# * Hot-Spot-Multi	247	Multiple hot spots on a thin film module.
#
# * Shadowing	1056	Sunlight obstructed by vegetation, man-made structures, or adjacent rows.
#
# * Diode	1,499	Activated bypass diode, typically 1/3 of module.
#
# * Diode-Multi	175	Multiple activated bypass diodes, typically affecting 2/3 of module.
#
# * Vegetation	1,639	Panels blocked by vegetation.
#
# * Soiling	205	Dirt, dust, or other debris on surface of module.
# Offline-Module	828	Entire module is heated.
#
# * No-Anomaly	10,000	Nominal solar module.
#
# * Dataset overview - https://ai4earthscience.github.io/iclr-2020-workshop/papers/ai4earth22.pdf

# %%
# import necessary libraries
# !pip install tensorflow
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import os, random
from tensorflow.keras import Sequential, Model, Input
from tensorflow.keras.layers import Conv2D, MaxPool2D, InputLayer, Dense, Flatten, Activation, Dropout, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import image_dataset_from_directory
from sklearn.metrics import classification_report, confusion_matrix
# Out:
# ...
# 2025-04-12 18:17:38.027147: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744481858.219801      73 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744481858.274744      73 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# import libraries
import os
import zipfile

# # Download the ZIP file
# !wget https://github.com/RaptorMaps/InfraredSolarModules/raw/refs/heads/master/2020-02-14_InfraredSolarModules.zip -O InfraredSolarModules.zip

# Unzip the downloaded file
with zipfile.ZipFile('InfraredSolarModules.zip', 'r') as zip_ref:
  zip_ref.extractall()

# rename the dataset
os.rename('InfraredSolarModules', 'InfraredSolarModules')

# Remove the ZIP dataset
os.remove('InfraredSolarModules.zip')
# Out:
# --2025-04-12 18:17:50--  https://github.com/RaptorMaps/InfraredSolarModules/raw/refs/heads/master/2020-02-14_InfraredSolarModules.zip
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/RaptorMaps/InfraredSolarModules/refs/heads/master/2020-02-14_InfraredSolarModules.zip [following]
# --2025-04-12 18:17:50--  https://raw.githubusercontent.com/RaptorMaps/InfraredSolarModules/refs/heads/master/2020-02-14_InfraredSolarModules.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15495990 (15M) [application/zip]
# Saving to: ‘InfraredSolarModules.zip’
#
# ...

# %% [markdown]
# ## 2.0 Exploratory Data Analysis

# %%
# list the files of solar panels classes
# !ls /content/InfraredSolarModules/images
# Out:
# ls: cannot access '/content/InfraredSolarModules/images': No such file or directory

# %%
# get the total number of images
import os

# get the image location and meta json path
image_path = '/kaggle/working/InfraredSolarModules/images'
json_path = '/kaggle/working/InfraredSolarModules/module_metadata.json'

# image files stored by getting the list directory of the image location and goes through each image being f that ends with .jpg
image_files = [f for f in os.listdir(image_path) if f.endswith('.jpg')]

# print the total number of images.
print(f"Total number of images: {len(image_files)}")
# Out:
# Total number of images: 20000

# %%
# get the class names programmatically
import pathlib
import numpy as np

data_dir = pathlib.Path(image_path)   # set it as a path object
class_names = np.array(sorted([item.name for item in data_dir.glob('*')]))  # created a list of class names from the train sub directories

print(class_names)
# Out:
# ['0.jpg' '1.jpg' '10.jpg' ... '9997.jpg' '9998.jpg' '9999.jpg']

# %%
# import json
import json

# get the json file path of the solar infrared module values
json_file_path = json_path

# Convert JSON file to Python dictionary
with open('/kaggle/working/InfraredSolarModules/module_metadata.json', 'r') as json_file:
  python_data = json.load(json_file)

python_data
# Out:
# {'13357': {'image_filepath': 'images/13357.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '13356': {'image_filepath': 'images/13356.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '19719': {'image_filepath': 'images/19719.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '11542': {'image_filepath': 'images/11542.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '11543': {'image_filepath': 'images/11543.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '11540': {'image_filepath': 'images/11540.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '11541': {'image_filepath': 'images/11541.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '11546': {'image_filepath': 'images/11546.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '11547': {'image_filepath': 'images/11547.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '11544': {'image_filepath': 'images/11544.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '11545': {'image_filepath': 'images/11545.jpg',
#   'anomaly_class': 'No-Anomaly'},
# ...

# %%
import os
import random
import json
import matplotlib.pyplot as plt

def view_images(image_dir, rows = 2, cols = 5, num_images = 10):
  """
  Views a random sample of images from a directory along with their anomaly class.

  Args:
    image_dir: The directory containing the images.
    num_images: The number of images to view.
  """
  # Load JSON data with anomaly classes
  json_file_path = json_path

  with open(json_file_path, 'r') as json_file:
    python_data = json.load(json_file)

  # Select random images
  image_files = [f for f in os.listdir(image_dir) if f.endswith('.jpg')]
  random_image_files = random.sample(image_files, min(num_images, len(image_files)))

  plt.figure(figsize=(15, 10))

  for i, image_file in enumerate(random_image_files):
    img_path = os.path.join(image_dir, image_file)
    img = plt.imread(img_path)

    # Extract anomaly class from JSON data
    image_filename = os.path.splitext(image_file)[0]  # Remove file extension
    anomaly_class = python_data.get(image_filename, {}).get('anomaly_class', 'Unknown')  # Get anomaly class, default to 'Unknown'

    plt.subplot(rows, cols, i + 1)
    plt.imshow(img)
    plt.title(f"Anomaly Class: {anomaly_class}")  # Title for each image
    plt.axis('off')

  plt.tight_layout()
  plt.show()

# Example usage
view_images(image_dir=image_path)

# %%
import os
import random
import json
import matplotlib.pyplot as plt
import tensorflow as tf

def view_images(image_dir, num_images=10, rows = 2, cols = 5):
  """
  Views a random sample of images from a directory along with their anomaly class, resizing them to 640x640.

  Args:
    image_dir: The directory containing the images.
    num_images: The number of images to view.
  """
  # Load JSON data with anomaly classes
  json_file_path = json_path

  with open(json_file_path, 'r') as json_file:
    python_data = json.load(json_file)

  # Select random images
  image_files = [f for f in os.listdir(image_dir) if f.endswith('.jpg')]
  random_image_files = random.sample(image_files, min(num_images, len(image_files)))

  plt.figure(figsize=(15, 10))

  for i, image_file in enumerate(random_image_files):
    img_path = os.path.join(image_dir, image_file)

    # Read the image
    img = tf.io.read_file(img_path)
    img = tf.image.decode_jpeg(img, channels=3)

    # Resize the image to 640x640
    img = tf.image.resize(img, [224, 224])

    # Convert back to numpy for plotting
    img = img.numpy().astype("uint8")

    # Extract anomaly class from JSON data
    image_filename = os.path.splitext(image_file)[0]  # Remove file extension
    anomaly_class = python_data.get(image_filename, {}).get('anomaly_class', 'Unknown')  # Get anomaly class, default to 'Unknown'

    plt.subplot(rows, cols, i + 1)
    plt.imshow(img)
    plt.title(f"Anomaly Class: {anomaly_class}")  # Title for each image
    plt.axis('off')

  plt.tight_layout()
  plt.show()

# Example usage
view_images(image_dir=image_path)
# Out:
# I0000 00:00:1744481875.801446      73 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %% [markdown]
# ## 3.0 Data Preprocessing

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 📦 Preprocessing & Dataset Pipeline

# %%
import os
import json
import tensorflow as tf
from sklearn.model_selection import train_test_split

# 1. Load metadata
with open(json_path, 'r') as f:
  metadata = json.load(f)

# 2. Create class-to-index mapping
classes = sorted({v['anomaly_class'] for v in metadata.values()})
class_to_idx = {cls: i for i, cls in enumerate(classes)}
print(f"Classes found: {class_to_idx}")

# # 3. Preprocessing function (resize + normalize)
# def preprocess_image(image):

#   image = tf.image.resize(image, [224, 224])
#   image = image / 255.0

#   return image

def preprocess_image(image):
  image = tf.image.resize(image, [224, 224])

  # If image has shape (H, W, 1), convert to RGB
  if image.shape[-1] == 1:
    image = tf.image.grayscale_to_rgb(image)

  image = image / 255.0
  return image

# 4. Create list of image paths and labels
image_dir = image_path
image_paths = []
labels = []

for fname in os.listdir(image_dir):

  if fname.endswith('.jpg'):

    img_id = os.path.splitext(fname)[0]
    label = metadata.get(img_id, {}).get('anomaly_class')

    if label in class_to_idx:

      image_paths.append(os.path.join(image_dir, fname))
      labels.append(class_to_idx[label])

# 5. Use train_test_split from sklearn
X_train, X_test, y_train, y_test = train_test_split(image_paths, labels, test_size=0.1, random_state=42, shuffle = True)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42, shuffle = True)

# setup augmentation
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.1),
    tf.keras.layers.RandomZoom(0.1),
    tf.keras.layers.RandomContrast(0.1)
])

# 6. Function to create TensorFlow dataset
def build_tf_dataset(paths, labels, batch_size=32, shuffle=True, training = False):

  dataset = tf.data.Dataset.from_tensor_slices((paths, labels))

  def load_img(path, label):

    image = tf.io.read_file(path)
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.adjust_contrast(image, 2.0)
    image = preprocess_image(image)

    # apply data augmentation to the training data
    if training:

      image = data_augmentation(image)

    return image, label

  dataset = dataset.map(load_img, num_parallel_calls=tf.data.AUTOTUNE)

  if shuffle:

    dataset = dataset.shuffle(buffer_size=1000)

  return dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)

# 7. Build datasets
train_ds = build_tf_dataset(X_train, y_train, training = True, shuffle = True)
val_ds = build_tf_dataset(X_val, y_val, shuffle=False, training = False)
test_ds = build_tf_dataset(X_test, y_test, shuffle=False, training = False)

# 8. Print sizes
print(f"Train samples: {len(X_train)}")
print(f"Validation samples: {len(X_val)}")
print(f"Test samples: {len(X_test)}")
# Out:
# Classes found: {'Cell': 0, 'Cell-Multi': 1, 'Cracking': 2, 'Diode': 3, 'Diode-Multi': 4, 'Hot-Spot': 5, 'Hot-Spot-Multi': 6, 'No-Anomaly': 7, 'Offline-Module': 8, 'Shadowing': 9, 'Soiling': 10, 'Vegetation': 11}
# Train samples: 14400
# Validation samples: 3600
# Test samples: 2000

# %% [markdown]
# lets view the training data as a numpy array

# %%
# view the training data numpy array form
image_batch, label_batch = next(iter(train_ds))

for image, label in zip(image_batch, label_batch):
  image = image.numpy()
  label = label.numpy()

print(f"Image: {image}")
print(f"Label: {label}")
# Out:
# Image: [[[0.77483433 0.77483433 0.77483433]
#   [0.7768151  0.7768151  0.7768151 ]
#   [0.77858377 0.77858377 0.77858377]
#   ...
#   [0.7882045  0.7882045  0.7882045 ]
#   [0.7893582  0.7893582  0.7893582 ]
#   [0.79059535 0.79059535 0.79059535]]
#
#  [[0.77104765 0.77104765 0.77104765]
#   [0.7726829  0.7726829  0.7726829 ]
#   [0.7742096  0.7742096  0.7742096 ]
#   ...
#   [0.7888992  0.7888992  0.7888992 ]
#   [0.7902031  0.7902031  0.7902031 ]
#   [0.7915223  0.7915223  0.7915223 ]]
#
#  [[0.76696    0.76696    0.76696   ]
#   [0.7684894  0.7684894  0.7684894 ]
#   [0.76991403 0.76991403 0.76991403]
#   ...
#   [0.78984785 0.78984785 0.78984785]
#   [0.79116726 0.79116726 0.79116726]
#   [0.79248655 0.79248655 0.79248655]]
#
#  ...
#
#  [[0.623664   0.623664   0.623664  ]
#   [0.6152046  0.6152046  0.6152046 ]
#   [0.60684985 0.60684985 0.60684985]
#   ...
#   [0.64722764 0.64722764 0.64722764]
#   [0.6505357  0.6505357  0.6505357 ]
#   [0.6537389  0.6537389  0.6537389 ]]
#
# ...

# %% [markdown]
# Now lets view the preprocessed thermal image in the training dataset.

# %%
# !pip install opencv-python

# %%
import random
import matplotlib.pyplot as plt
import numpy as np
import cv2

# Reverse the class mapping to get index -> class name
idx_to_class = {v: k for k, v in class_to_idx.items()}

# Get a batch of images and labels from the training dataset
image_batch, label_batch = next(iter(train_ds))

# Print the shape of the image batch
print(f"Shape of full image batch: {image_batch.shape}")

# Choose a random subset of images to display (max 5)
num_images_to_display = min(10, len(image_batch))
random_indices = random.sample(range(len(image_batch)), num_images_to_display)

# Create a figure for plotting
plt.figure(figsize=(15, 15))

for i, index in enumerate(random_indices):
  image = image_batch[index].numpy()  # Convert image tensor to NumPy array
  label = label_batch[index].numpy()  # Convert label tensor to NumPy

  # Resize the image to 224x224 using OpenCV
  image_resized = cv2.resize(image, (224, 224))

  print(f"Shape of image {i}: {image.shape}")

  # Apply thermal effect using 'jet' colormap on the first channel
  thermal_image = np.clip(image * 255, 0, 255).astype(np.uint8)
  thermal_image = plt.cm.jet(thermal_image[..., 0])  # Apply colormap on 1st channel
  thermal_image = (thermal_image[..., :3] * 255).astype(np.uint8)  # Keep RGB only

  # Plot each image with label as text
  plt.subplot(5, 5, i + 1)
  plt.imshow(thermal_image)
  plt.title(f"Class: {idx_to_class[label]}")
  plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Shape of full image batch: (32, 224, 224, 3)
# Shape of image 0: (224, 224, 3)
# Shape of image 1: (224, 224, 3)
# Shape of image 2: (224, 224, 3)
# Shape of image 3: (224, 224, 3)
# Shape of image 4: (224, 224, 3)
# Shape of image 5: (224, 224, 3)
# Shape of image 6: (224, 224, 3)
# Shape of image 7: (224, 224, 3)
# Shape of image 8: (224, 224, 3)
# Shape of image 9: (224, 224, 3)

# %% [markdown]
# ## 4.0 Deep Learning Model

# %% [markdown]
# ### 4.1 Using ResNet50V2 pre-trained DL CNN Model

# %%
# import libraries
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import ResNet50V2

# define model architecture
def create_model(num_classes):
  '''using a pretrained model
  '''
  # setup random seed
  tf.random.set_seed(42)

  # load the model
  base_model = ResNet50V2(input_shape = (224, 224, 3), include_top = False, weights = 'imagenet')

  # freeze the base model layers
  base_model.trainable = False

  # create model architecture
  model = models.Sequential([
      base_model,
      layers.GlobalAveragePooling2D(),
      layers.Dense(512, activation = 'relu'),
      layers.Dropout(0.5),
      layers.Dense(num_classes, activation = 'softmax')
  ])

  # compile model
  model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = 0.001),
                loss = 'sparse_categorical_crossentropy',
                metrics = ['accuracy'])

  return model

# %%
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

# Your class names
class_names = ['Cell', 'Cell-Multi', 'Cracking', 'Diode', 'Diode-Multi', 'Hot-Spot',
               'Hot-Spot-Multi', 'No-Anomaly', 'Offline-Module', 'Shadowing',
               'Soiling', 'Vegetation']

# Convert class names to indices if you haven't already
class_indices = {name: i for i, name in enumerate(class_names)}

# Suppose you have y_train as your list/array of class indices
# Example: y_train = [0, 1, 1, 8, 8, 8, 5, 2, 11, 11, 11, 11, ...]

# Compute class weights
class_weights = compute_class_weight(class_weight='balanced',
                                     classes=np.unique(y_train),
                                     y=y_train)

# Clip the class weights to a max and min value
max_allowed_weight = 4.0  # Set a max cap for the weights
min_allowed_weight = 0.5  # Set a min cap for the weights

# Clip the class weights
clipped_class_weights = {i: max(min(weight, max_allowed_weight), min_allowed_weight)
                         for i, weight in enumerate(class_weights)}

# Convert the clipped weights to dictionary format expected by Keras
clipped_class_weights = dict(clipped_class_weights)

# Ensure that class_weights is in the correct dictionary format
class_weights = dict(enumerate(clipped_class_weights))

# Print clipped class weights to verify
print("Clipped class weights:")
print(clipped_class_weights)
# Out:
# Clipped class weights:
# {0: 0.8759124087591241, 1: 1.2987012987012987, 2: 1.8181818181818181, 3: 1.098901098901099, 4: 4.0, 5: 4.0, 6: 4.0, 7: 0.5, 8: 1.9834710743801653, 9: 1.5132408575031526, 10: 4.0, 11: 1.0195412064570943}

# %%
# initiate the model
model = create_model(num_classes = len(class_to_idx))

initial_epochs = 10

# train the model
history = model.fit(train_ds, epochs = initial_epochs, validation_data = val_ds, verbose = 1, class_weight = class_weights)
# Out:
# ...
# 94668760/94668760 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/10
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1744481909.901263     133 service.cc:148] XLA service 0x7975f0003ca0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1744481909.902095     133 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1744481911.715112     133 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   3/450 ━━━━━━━━━━━━━━━━━━━━ 23s 53ms/step - accuracy: 0.2014 - loss: 13.6007
# I0000 00:00:1744481916.894684     133 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 106s 187ms/step - accuracy: 0.5129 - loss: 7.6470 - val_accuracy: 0.6158 - val_loss: 1.9642
# Epoch 2/10
# ...

# %% [markdown]
# Let's view the accuracy and loss curve

# %%
# view the model loss and accuracy curve
import matplotlib.pyplot as plt

# extract accuracy and loss
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

train_loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(train_acc) + 1)

# plot for accuracy
plt.figure(figsize = (10, 10))
plt.subplot(2, 1, 1)

plt.plot(epochs, train_acc, label = 'Train Accuracy')
plt.plot(epochs, val_acc, label = 'Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# plot loss
plt.subplot(2, 1, 2)
plt.plot(epochs, train_loss, label = 'Train loss')
plt.plot(epochs, val_loss, label = 'Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()

# %% [markdown]
# ### 4.2 Fine Tune ResNet50V2 pre-trained Deep Learning CNN Model

# %% [markdown]
# Time to fine-tune the ResNet50V2 model and improve the performance.

# %%
# 1. Load base model
base_model = tf.keras.applications.ResNet50V2(
    include_top=False,
    input_shape=(224, 224, 3),
    weights='imagenet'
)
base_model.trainable = False  # Freeze for now

# 2. Build the full model
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(224, 224, 3)),
    base_model,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(len(class_to_idx), activation='softmax')
])

model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ resnet50v2 (Functional)              │ (None, 7, 7, 2048)          │      23,564,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d_1           │ (None, 2048)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 12)                  │          24,588 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 23,589,388 (89.99 MB)
# ...

# %%
# setup epochs to be added with the final epoch
fine_tune_epochs = 10
total_epoch = initial_epochs + fine_tune_epochs

# Unfreeze top N layers
unfreeze_layers = 60
for layer in base_model.layers[-unfreeze_layers:]:
  layer.trainable = True

# Recompile with low learning rate
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# train the model
history_fine_tune_model = model.fit(train_ds, validation_data = val_ds, epochs = total_epoch, initial_epoch = len(history.epoch), class_weight = class_weights, verbose = 1)
# Out:
# Epoch 11/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 128s 210ms/step - accuracy: 0.3725 - loss: 10.5776 - val_accuracy: 0.6219 - val_loss: 1.5345
# Epoch 12/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 95s 200ms/step - accuracy: 0.5933 - loss: 5.6776 - val_accuracy: 0.6672 - val_loss: 1.4497
# Epoch 13/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 95s 200ms/step - accuracy: 0.6370 - loss: 4.8162 - val_accuracy: 0.6803 - val_loss: 1.4231
# Epoch 14/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 96s 203ms/step - accuracy: 0.6558 - loss: 4.3792 - val_accuracy: 0.6961 - val_loss: 1.3782
# Epoch 15/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 95s 202ms/step - accuracy: 0.6676 - loss: 4.0510 - val_accuracy: 0.6997 - val_loss: 1.3886
# Epoch 16/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 95s 202ms/step - accuracy: 0.6800 - loss: 3.8043 - val_accuracy: 0.7069 - val_loss: 1.3877
# Epoch 17/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 94s 199ms/step - accuracy: 0.6902 - loss: 3.5399 - val_accuracy: 0.7128 - val_loss: 1.3944
# Epoch 18/20
# ...

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ resnet50v2 (Functional)              │ (None, 7, 7, 2048)          │      23,564,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d_1           │ (None, 2048)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 12)                  │          24,588 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 58,053,158 (221.46 MB)
# ...

# %%
len(model.trainable_variables)
# Out:
# 56

# %%
import matplotlib.pyplot as plt

# Initialize if this is your first time plotting
# (skip this if continuing from a previous history)
train_acc = history.history['accuracy'] + history_fine_tune_model.history['accuracy']
val_acc = history.history['val_accuracy'] + history_fine_tune_model.history['val_accuracy']

train_loss = history.history['loss'] + history_fine_tune_model.history['loss']
val_loss = history.history['val_loss'] + history_fine_tune_model.history['val_loss']

epochs = range(1, len(train_acc) + 1)

# Set the epoch where fine-tuning started
fine_tuning_epoch = len(history.history['accuracy']) + 1  # +1 to mark the next epoch visually

# Plotting
plt.figure(figsize=(10, 10))

# Accuracy Plot
plt.subplot(2, 1, 1)
plt.plot(epochs, train_acc, label='Train Accuracy')
plt.plot(epochs, val_acc, label='Validation Accuracy')
plt.axvline(x=fine_tuning_epoch, color='red', linestyle='--', label='Fine-Tuning Start')
plt.title('Training and Validation Accuracy after fine tuned')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Loss Plot
plt.subplot(2, 1, 2)
plt.plot(epochs, train_loss, label='Train Loss')
plt.plot(epochs, val_loss, label='Validation Loss')
plt.axvline(x=fine_tuning_epoch, color='red', linestyle='--', label='Fine-Tuning Start')
plt.title('Training and Validation Loss after fine tuned')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.savefig('model results after fine tuning.png')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4.3 Evaluating the model on the test dataset.

# %%
test_loss, test_accuracy = model.evaluate(test_ds)

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.7327 - loss: 1.3399
# Test Loss: 1.4189
# Test Accuracy: 0.7250

# %%
# make predictions
predictions = model.predict(test_ds)

# get the predicted classes (1,7,11, 8, etc)
predicted_classes = np.argmax(predictions, axis = 1)
predicted_classes
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 93ms/step
# array([1, 7, 7, ..., 2, 7, 7])

# %%
from sklearn.metrics import classification_report, confusion_matrix

# Assuming test_ds yields (features, labels)
true_labels = np.concatenate([y.numpy() for x, y in test_ds], axis=0)

print("Classification Report:")
print(classification_report(true_labels, predicted_classes))

print("Confusion Matrix:")
print(confusion_matrix(true_labels, predicted_classes))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       182
#            1       0.42      0.10      0.17       125
#            2       0.64      0.59      0.61        97
#            3       0.94      0.85      0.89       148
#            4       0.90      0.45      0.60        20
#            5       0.32      0.31      0.31        26
#            6       0.45      0.38      0.41        24
#            7       0.85      0.96      0.90      1023
#            8       0.58      0.52      0.55        87
#            9       0.59      0.54      0.56        91
#           10       0.16      0.47      0.24        15
#           11       0.44      0.87      0.58       162
#
#     accuracy                           0.73      2000
#    macro avg       0.52      0.50      0.49      2000
# weighted avg       0.67      0.72      0.68      2000
#
# Confusion Matrix:
# [[  0  16  10   3   0   6   0  42   1  10   9  85]
# ...

# %%
class_to_idx.keys()
# Out:
# dict_keys(['Cell', 'Cell-Multi', 'Cracking', 'Diode', 'Diode-Multi', 'Hot-Spot', 'Hot-Spot-Multi', 'No-Anomaly', 'Offline-Module', 'Shadowing', 'Soiling', 'Vegetation'])

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Class names
class_names = ['Cell', 'Cell-Multi', 'Cracking', 'Diode', 'Diode-Multi', 'Hot-Spot', 'Hot-Spot-Multi',
               'No-Anomaly', 'Offline-Module', 'Shadowing', 'Soiling', 'Vegetation']

# Compute the confusion matrix
cm = confusion_matrix(true_labels, predicted_classes)

# Create a figure and axis
fig, ax = plt.subplots(figsize=(10, 10))  # Slightly larger for readability

# Display the confusion matrix with class labels and a new color map
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Oranges, ax=ax)

# Title and rotation of x-axis labels
ax.set_title('Confusion Matrix', fontsize=12)
plt.xticks(rotation=90)  # Set x-axis tick labels to vertical

# Show the plot
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Your class names
class_names = ['Cell', 'Cell-Multi', 'Cracking', 'Diode', 'Diode-Multi', 'Hot-Spot',
               'Hot-Spot-Multi', 'No-Anomaly', 'Offline-Module', 'Shadowing', 'Soiling', 'Vegetation']

# Example data (replace with your actual true and predicted labels)
# Make sure these are the numeric class indices, e.g., [0, 1, 2, 3, ...]
# true_labels = [0, 1, 2, 3, 4]  # your true labels here
# predicted_classes = [0, 1, 2, 3, 5]  # your predicted labels here

# Ensure both arrays have the same length
assert len(true_labels) == len(predicted_classes), "Mismatch between number of true and predicted labels"

# One-hot encode the true and predicted labels
true_df = pd.get_dummies(true_labels, dtype=int)
pred_df = pd.get_dummies(predicted_classes, dtype=int)

# Ensure the columns are the same as class names
true_df.columns = class_names[:len(true_df.columns)]  # match columns to actual class names
pred_df.columns = class_names[:len(pred_df.columns)]  # match columns to actual class names

# If any class index is missing, add it with zeroes
for i, class_name in enumerate(class_names):
    if class_name not in true_df.columns:
        true_df[class_name] = 0
    if class_name not in pred_df.columns:
        pred_df[class_name] = 0

# Combine them into one DataFrame for correlation calculation
combined_df = pd.concat([true_df, pred_df], axis=1)

# Compute the correlation matrix between true and predicted
correlation_matrix = combined_df.corr().iloc[:len(class_names), len(class_names):]

# Plot the heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix,
            annot=True,
            cmap="YlGnBu",
            fmt=".2f",
            xticklabels=class_names,
            yticklabels=class_names,
            cbar_kws={'label': 'Correlation'})

plt.title("Correlation Matrix: True vs Predicted Classes", fontsize=14)
plt.xlabel("Predicted Class", fontsize=12)
plt.ylabel("True Class", fontsize=12)
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1

# %% [markdown]
# ### 4.4 Make predictions on the test dataset

# %%
class_names = ['Cell', 'Cell-Multi', 'Cracking', 'Diode', 'Diode-Multi', 'Hot-Spot', 'Hot-Spot-Multi',
               'No-Anomaly', 'Offline-Module', 'Shadowing', 'Soiling', 'Vegetation']

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import random
import cv2

def predict_from_test(test_ds, model, class_names, num_samples=5):
    """
    Predict and display random samples from the test dataset with thermal effect visualization.

    Parameters:
    - test_ds: tf.data.Dataset, the test dataset.
    - model: Trained TensorFlow model.
    - class_names: List of class labels.
    - num_samples: Number of random samples to display from one batch.
    """

    # Take a single batch from the test dataset
    for images, labels in test_ds.take(1):
        plt.figure(figsize=(num_samples * 3, 4))  # Set figure size dynamically

        # Get batch size and select random indices to display
        batch_size = images.shape[0]
        random_indices = random.sample(range(batch_size), min(num_samples, batch_size))

        for i, idx in enumerate(random_indices):
            img = images[idx]                # Get the image at random index
            true_label = labels[idx].numpy() # Convert label tensor to integer

            # Convert grayscale images to RGB
            if img.shape[-1] == 1:
                img = tf.image.grayscale_to_rgb(img)

            # Resize image to 224x224 as required by most models (e.g., MobileNet, AlexNet, etc.)
            resized_img = tf.image.resize(img, [224, 224])
            img_batch = tf.expand_dims(resized_img, axis=0)  # Add batch dimension

            # Make prediction
            predictions = model.predict(img_batch, verbose=0)
            predicted_label = tf.argmax(predictions[0]).numpy()

            # Get predicted and true class names
            pred_class = class_names[predicted_label]
            true_class = class_names[true_label]

            # Set the title color (green if correct, red if incorrect)
            color = "green" if predicted_label == true_label else "red"

            # Convert image tensor to NumPy and scale pixel values to 0-255
            np_img = img.numpy()
            np_img = np.clip(np_img * 255, 0, 255).astype(np.uint8)

            # Apply thermal effect:
            # - If grayscale, apply colormap on the single channel.
            # - If RGB, convert to grayscale first using OpenCV, then apply colormap.
            if np_img.shape[-1] == 1:
                thermal_image = plt.cm.jet(np_img[..., 0])  # Use jet colormap
            else:
                gray_like = cv2.cvtColor(np_img, cv2.COLOR_RGB2GRAY)
                thermal_image = plt.cm.jet(gray_like)

            # Remove alpha channel and scale back to RGB (0-255)
            thermal_image = (thermal_image[..., :3] * 255).astype(np.uint8)

            # Plot the image with predicted and true labels
            plt.subplot(1, num_samples, i + 1)
            plt.imshow(thermal_image)
            plt.axis('off')
            plt.title(f"True: {true_class}\nPred: {pred_class}", color=color, fontsize=10)

        plt.tight_layout()
        plt.show()

# %%
predict_from_test(test_ds, model, class_names = class_names)

# %% [markdown]
# ## 5.0 Saving the model

# %%
# save the model
model.save('resnet50v2_fine_tuned.h5')

# %%
# reload the saved model
reload_model = tf.keras.models.load_model('resnet50v2_fine_tuned.h5')
reload_model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ resnet50v2 (Functional)              │ (None, 7, 7, 2048)          │      23,564,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d_1           │ (None, 2048)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 12)                  │          24,588 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 23,589,390 (89.99 MB)
# ...

# %% [markdown]
# ## 6.0 Deploying the Model

# %%
# to deploy the model on streamlit i will first need to put it in a folder structure
import os

# create main app folder
project_dir = 'my-streamlit-app'

# directories
os.makedirs(os.path.join(project_dir, 'model'), exist_ok = True)
os.makedirs(os.path.join(project_dir, 'data'), exist_ok = True)

print(f'Project Structure created at {project_dir}')
# Out:
# Project Structure created at my-streamlit-app

# %%
# save the model in the my-streamlit-app/model folder
model.save(os.path.join(project_dir, 'model', 'resnet50v2_fine_tuned.h5'))
print('Model saved to the directory')
# Out:
# Model saved to the directory

# %%
# install streamlit
# !pip install streamlit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 65.4 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 95.9 MB/s eta 0:00:00:00:01
# ...

# %%
app_code = """
import streamlit as st
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
from PIL import Image

# Load the model
model = load_model("my-streamlit-app/model/resnet50v2_fine_tuned.h5")

# Define class labels
class_names = [
    'Cell', 'Cell-Multi', 'Cracking', 'Diode', 'Diode-Multi',
    'Hot-Spot', 'Hot-Spot-Multi', 'No-Anomaly', 'Offline-Module',
    'Shadowing', 'Soiling', 'Vegetation'
]

st.title("🔍 Solar Panel Thermal Fault Detection")

uploaded_file = st.file_uploader("Upload a thermal image of a solar panel (grayscale or RGB)", type=["jpg", "jpeg", "png"])

if uploaded_file is not None:
    img = Image.open(uploaded_file)
    st.image(img, caption="Uploaded Image", use_column_width=True)

    # Check if image is grayscale
    if img.mode == "L":
        st.warning("Grayscale image detected. Converting to RGB...")
        img = img.convert("RGB")
    else:
        st.info("RGB or color image detected. Proceeding with standard preprocessing...")

    # Resize and preprocess
    img = img.resize((224, 224))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = img_array / 255.0  # Normalize

    # Make prediction
    preds = model.predict(img_array)
    class_idx = np.argmax(preds[0])
    confidence = preds[0][class_idx]
    predicted_label = class_names[class_idx]

    st.success(f"🔎 Predicted Fault: **{predicted_label}**")
    st.info(f"🧠 Confidence: **{confidence * 100:.2f}%**")
"""

# Save it into app.py
with open(os.path.join(project_dir, 'app.py'), 'w') as f:
  f.write(app_code.strip())

print("✅ app.py has been created in the project folder!")
# Out:
# ✅ app.py has been created in the project folder!

# %%
import os

# Define the path to the 'my-streamlit-app' folder
project_dir = 'my-streamlit-app'

# Create 'requirements.txt' inside the 'my-streamlit-app' folder
requirements_path = os.path.join(project_dir, 'requirements.txt')

# Write required libraries to the 'requirements.txt' file
with open(requirements_path, 'w') as f:
  f.write('streamlit\n')
  f.write('tensorflow\n')
  f.write('numpy\n')
  f.write('pillow\n')

print(f"requirements.txt created at: {requirements_path}")
# Out:
# requirements.txt created at: my-streamlit-app/requirements.txt
