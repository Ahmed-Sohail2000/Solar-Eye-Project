# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahmed-Sohail2000/Solar-Eye-Project/blob/main/Solar_Eye_%F0%9F%8C%9E%F0%9F%91%80_Solar_Image_Classification_Project_with_Deep_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Solar Eye 🌞👀

# %% [markdown]
# ## Project Scope and Objectives 🎯
#
# A multi-class classification problem to classify the faults of solar pv modules using UAV drones and deep learning model.
#
# This project aims to develop an AI-driven system that utilizes drone technology to capture images or videos of solar photovoltaic (PV) modules for the purpose of predicting and classifying faults. The integration of AI with drone imagery can enhance the efficiency and effectiveness of solar panel inspections, leading to improved maintenance and operational reliability.
#
# The solareye project falls under the Computer Vision category in Deep Learning and will implement CNN model architecture.
#
# The study employs computer vision techniques to detect various errors in solar cell manufacture usingthe YOLOv8 architecture; this new technique can address the drawbacks of conventional detection techniques,including their rigidity, slowness, and reduced accuracy. The experimental findings prove that the proposed approach can effectively and accurately detect numerous defaults that are present on solar cell surfaces, short-circuit, fracture, and horizontal dissolution.
#
# The objectives of the project would be:
#
# **Automate Inspections:** Replace manual inspections with drone-based automated systems, reducing labor costs and time.
#
# **Enhance Accuracy:** Achieve >90% accuracy in fault detection and classification using AI models.
#
# **Increase Efficiency:** Reduce inspection time by 50% compared to traditional methods.
#
# **Provide Actionable Insights:** Deliver detailed reports to maintenance teams for timely repairs.
#
# The project is referenced by a journal article called [CNN-based automatic detection of photovoltaic solar module
# anomalies in infrared images: a comparative study]
# ](https://www.researchgate.net/publication/383036389_CNN-based_automatic_detection_of_photovoltaic_solar_module_anomalies_in_infrared_images_a_comparative_study)
#
#
# ## Key Project Components 🛠️
#
# A. Drone Setup
#
# Drone Selection:
# Model: DJI Matrice 300 RTK or similar industrial-grade drones.
# Payload Capacity: Must support thermal and visible spectrum cameras.
# Flight Time: Minimum 30 minutes for large solar farms.
# Camera Specifications:
# Thermal Camera: FLIR Vue Pro or similar, with a resolution of 640x512 pixels and a thermal sensitivity of <50mK.
# Visible Spectrum Camera: 20MP or higher resolution for detailed visual inspection.
# Flight Planning:
# Software: Use DJI Pilot or Pix4D for automated flight planning.
# Parameters: Altitude of 10-20 meters, speed of 2-3 m/s, and 70% image overlap for comprehensive coverage.
#
# B. Data Collection
#
# Image/Video Capture:
# Frequency: Weekly or bi-weekly inspections, depending on the size of the solar farm.
# Conditions: Capture images during clear weather and at consistent times (e.g., midday) to minimize variations.
# Annotation:
# Tools: Use LabelImg or CVAT for annotating images with bounding boxes and labels (e.g., cracks, hot spots, soiling).
# Dataset Size: Aim for at least 10,000 annotated images for robust model training.
#
# C. AI Model Development
#
# Model Selection:
# YOLOv8: For real-time object detection and classification.
# EfficientNet-B4: For high-accuracy image classification.
# Transfer Learning: Use pre-trained models on ImageNet and fine-tune them on your dataset.
# Data Preprocessing:
# Resizing: Resize images to 416x416 pixels for YOLO or 224x224 pixels for EfficientNet.
# Augmentation: Apply techniques like rotation, flipping, and brightness adjustment to increase dataset diversity.
# Normalization: Normalize pixel values to [0, 1] for better model convergence.
# Training:
# Framework: TensorFlow or PyTorch.
# Hyperparameters: Learning rate of 0.001, batch size of 32, and 50-100 epochs.
# Metrics: Monitor accuracy, precision, recall, and F1 score during training.
#
# D. Integration and Deployment
#
# Real-Time Processing:
# Edge Computing: Use NVIDIA Jetson Xavier or similar hardware for onboard processing.
# Cloud Integration: Store and process data in the cloud (e.g., AWS or Google Cloud) for scalability.
# User Interface:
# Dashboard: Develop a web-based dashboard using React.js or Angular for real-time monitoring.
# Mobile App: Create an app using Flutter or React Native for field technicians.
# Alerts and Reporting:
# Notifications: Use SMS or email alerts for detected faults.
# Reports: Generate PDF reports with fault locations, classifications, and recommended actions.
#
# ## Project Approach 🪜
#
# Step-by-Step Approach
#
# Define Requirements:
# Identify the size of the solar farm, types of faults to detect, and user needs.
#
# Select Technology:
# Choose drones, cameras, and AI frameworks based on project requirements.
#
# Data Collection:
# Capture and annotate images/videos of solar panels.
#
# Model Development:
# Preprocess data, train the AI model, and evaluate performance.
#
# Integration:
# Integrate the AI model with the drone system and develop the user interface.
#
# Testing:
# Conduct field tests to validate the system’s performance.
#
# Deployment:
# Deploy the system for real-world use and train end-users.
#
# Monitoring and Maintenance:
# Continuously monitor the system and update the model as needed.
#
#
# ## Project Applications 🌏
#
# 1) Solar Panel Maintenance System:
#
#   * Develop a system that automatically assesses the condition of solar panels, providing insights into whether they are clean, damaged, dirty, etc.
#   * Implement a notification system to alert maintenance personnel when issues are detected.
#
# 2) Energy Production Optimization:
#
#   * Use the classification results to optimize the cleaning schedule for solar panels, ensuring they operate at peak efficiency.
#   * Implement an intelligent system that recommends optimal cleaning frequencies based on historical data.
#
# 3) Automated Inspection Drones:
#
#   * Integrate the image classification model with drones equipped with cameras for automated aerial inspections of large solar farms.
#   * Enable the drones to identify and document areas that require attention.
#
# 4) Remote Monitoring Dashboard:
#
#   * Develop a web-based dashboard that allows users to remotely monitor the status of solar panels in real-time.
#   * Provide visualization tools and historical data to track the performance of individual panels or entire solar arrays.
#
# 5) Predictive Maintenance:
#
#   * Implement predictive maintenance based on the classification results and historical data.
#   * Use machine learning algorithms to predict potential issues before they occur, allowing for proactive maintenance.
#
# 6) Performance Analytics:
#
#   * Provide detailed analytics on the performance of solar panels over time.
#   * Include metrics such as energy production, efficiency, and degradation rates.
#
# 7) Integration with Smart Grids:
#
#   * Explore integration possibilities with smart grid systems to optimize energy distribution based on the health of individual solar panels.
#
# 8) Educational Tools:
#
#   * Develop educational tools or resources that explain the importance of solar panel maintenance and how the image classification system works.
#
# 9) Research Collaboration:
#
#   * Collaborate with research institutions or environmental organizations to contribute data for broader research on the health and performance of solar energy systems
#
# ## Project Resources 📚
#
#   Resources Needed
#
#   Hardware:
#   Drones: DJI Matrice 300 RTK (2-3 units).
#   Cameras: FLIR Vue Pro (thermal) and Sony Alpha (visible spectrum).
#   Edge Computing: NVIDIA Jetson Xavier for onboard processing.
#
#   Software:
#   AI Frameworks: TensorFlow, PyTorch, or YOLOv8.
#   Annotation Tools: LabelImg or CVAT.
#   UI Development: React.js for the dashboard and Flutter for the mobile app.
#
#   Human Resources:
#   Data Scientists: For model development and training.
#   Drone Operators: For flight planning and execution.
#   Software Developers: For UI and system integration.
#
#   Additional Resources:
#
#   * Project Dataset - https://github.com/RaptorMaps/InfraredSolarModules
#   * TensorFlow - https://www.tensorflow.org/
#   * YOLOV8 Model - https://github.com/ultralytics/ultralytics
#   * Similar Computer Vision Problem - https://dev.mrdbourke.com/tensorflow-deep-learning/03_convolutional_neural_networks_in_tensorflow/
#   * Convolutional Neural Network - https://towardsdatascience.com/convolutional-neural-networks-explained-9cc5188c4939
#   * Basic Explanation of CNN - https://www.upgrad.com/blog/basic-cnn-architecture/
#   * Solar Cell Image Classification Steps - https://umairrafiq.medium.com/solar-cells-image-classification-using-dnn-deep-neural-networks-10479ed02c16
#   * Load and preprocess input images - https://www.tensorflow.org/tutorials/load_data/images
#
# **Journal Articles:**
#
#   1) Automatic detection of solar cell surface defects in electroluminescence images based on YOLOv8 algorithm - https://www.researchgate.net/publication/376124810_Automatic_detection_of_solar_cell_surface_defects_in_electroluminescence_images_based_on_YOLOv8_algorithm
#
#  2) Image based surface damage detection of renewable energy installations using a unified deep learning approach - https://www.sciencedirect.com/science/article/pii/S2352484721005102?ref=pdf_download&fr=RR-2&rr=8802fa115cdb126e

# %% [markdown]
# ## 1.0 Getting The Project Data

# %% [markdown]
# The dataset consists of 20,000 infrared images that are 24 by 40 pixels each. There are 12 defined classes of solar modules presented in this paper with 11 classes of different anomalies and the remaining class being No-Anomaly (i.e. the null case).
#
# * Cell	1,877	Hot spot occurring with square geometry in single cell.
#
# * Cell-Multi	1,288	Hot spots occurring with square geometry in multiple cells.
#
# * Cracking	941	Module anomaly caused by cracking on module surface.
#
# * Hot-Spot	251	Hot spot on a thin film module.
#
# * Hot-Spot-Multi	247	Multiple hot spots on a thin film module.
#
# * Shadowing	1056	Sunlight obstructed by vegetation, man-made structures, or adjacent rows.
#
# * Diode	1,499	Activated bypass diode, typically 1/3 of module.
#
# * Diode-Multi	175	Multiple activated bypass diodes, typically affecting 2/3 of module.
#
# * Vegetation	1,639	Panels blocked by vegetation.
#
# * Soiling	205	Dirt, dust, or other debris on surface of module.
# Offline-Module	828	Entire module is heated.
#
# * No-Anomaly	10,000	Nominal solar module.
#
# * Dataset overview - https://ai4earthscience.github.io/iclr-2020-workshop/papers/ai4earth22.pdf

# %%
# import necessary libraries
# !pip install tensorflow
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import os, random
from tensorflow.keras import Sequential, Model, Input
from tensorflow.keras.layers import Conv2D, MaxPool2D, InputLayer, Dense, Flatten, Activation, Dropout, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import image_dataset_from_directory
from sklearn.metrics import classification_report, confusion_matrix
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.13.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)

# %%
# import libraries
import os
import zipfile

# # Download the ZIP file
# !wget https://github.com/RaptorMaps/InfraredSolarModules/raw/refs/heads/master/2020-02-14_InfraredSolarModules.zip -O InfraredSolarModules.zip

# Unzip the downloaded file
with zipfile.ZipFile('InfraredSolarModules.zip', 'r') as zip_ref:
  zip_ref.extractall()

# rename the dataset
os.rename('InfraredSolarModules', 'InfraredSolarModules')

# Remove the ZIP dataset
os.remove('InfraredSolarModules.zip')
# Out:
# --2025-04-11 07:10:20--  https://github.com/RaptorMaps/InfraredSolarModules/raw/refs/heads/master/2020-02-14_InfraredSolarModules.zip
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com
# 12561.jpg  15133.jpg  17706.jpg  2278.jpg   4850.jpg  7422.jpg	9996.jpg
# 12562.jpg  15134.jpg  17707.jpg  2279.jpg   4851.jpg  7423.jpg	9997.jpg
# 12563.jpg  15135.jpg  17708.jpg  227.jpg    4852.jpg  7424.jpg	9998.jpg
# 12564.jpg  15136.jpg  17709.jpg  2280.jpg   4853.jpg  7425.jpg	9999.jpg
# 12565.jpg  15137.jpg  1770.jpg	 2281.jpg   4854.jpg  7426.jpg	999.jpg
# 12566.jpg  15138.jpg  17710.jpg  2282.jpg   4855.jpg  7427.jpg	99.jpg
# 12567.jpg  15139.jpg  17711.jpg  2283.jpg   4856.jpg  7428.jpg	9.jpg
# 12568.jpg  1513.jpg   17712.jpg  2284.jpg   4857.jpg  7429.jpg
# 12569.jpg  15140.jpg  17713.jpg  2285.jpg   4858.jpg  742.jpg
# 1256.jpg   15141.jpg  17714.jpg  2286.jpg   4859.jpg  7430.jpg
# 12570.jpg  15142.jpg  17715.jpg  2287.jpg   485.jpg   7431.jpg
# 12571.jpg  15143.jpg  17716.jpg  2288.jpg   4860.jpg  7432.jpg
# 12572.jpg  15144.jpg  17717.jpg  2289.jpg   4861.jpg  7433.jpg

# %%
# get the total number of images
import os

# get the image location and meta json path
image_path = '/content/InfraredSolarModules/images'
json_path = '/content/InfraredSolarModules/module_metadata.json'

# image files stored by getting the list directory of the image location and goes through each image being f that ends with .jpg
image_files = [f for f in os.listdir(image_path) if f.endswith('.jpg')]

# print the total number of images.
print(f"Total number of images: {len(image_files)}")
# Out:
# Total number of images: 20000

# %%
# get the class names programmatically
import pathlib
import numpy as np

data_dir = pathlib.Path(image_path)   # set it as a path object
class_names = np.array(sorted([item.name for item in data_dir.glob('*')]))  # created a list of class names from the train sub directories

print(class_names)
# Out:
# ['0.jpg' '1.jpg' '10.jpg' ... '9997.jpg' '9998.jpg' '9999.jpg']

# %%
# import json
import json

# get the json file path of the solar infrared module values
json_file_path = json_path

# Convert JSON file to Python dictionary
with open('/content/InfraredSolarModules/module_metadata.json', 'r') as json_file:
  python_data = json.load(json_file)

python_data
# Out:
# {'13357': {'image_filepath': 'images/13357.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '13356': {'image_filepath': 'images/13356.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '19719': {'image_filepath': 'images/19719.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '11542': {'image_filepath': 'images/11542.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '11543': {'image_filepath': 'images/11543.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '11540': {'image_filepath': 'images/11540.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '11541': {'image_filepath': 'images/11541.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '11546': {'image_filepath': 'images/11546.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '11547': {'image_filepath': 'images/11547.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '11544': {'image_filepath': 'images/11544.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '11545': {'image_filepath': 'images/11545.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '14545': {'image_filepath': 'images/14545.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '11548': {'image_filepath': 'images/11548.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '11549': {'image_filepath': 'images/11549.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '16426': {'image_filepath': 'images/16426.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '19927': {'image_filepath': 'images/19927.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '5988': {'image_filepath': 'images/5988.jpg', 'anomaly_class': 'Cell'},
#  '5989': {'image_filepath': 'images/5989.jpg', 'anomaly_class': 'Cell'},
#  '19399': {'image_filepath': 'images/19399.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '19398': {'image_filepath': 'images/19398.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '5982': {'image_filepath': 'images/5982.jpg', 'anomaly_class': 'Cell'},
#  '5983': {'image_filepath': 'images/5983.jpg', 'anomaly_class': 'Cell'},
#  '5980': {'image_filepath': 'images/5980.jpg', 'anomaly_class': 'Cell'},
#  '5981': {'image_filepath': 'images/5981.jpg', 'anomaly_class': 'Cell'},
#  '5986': {'image_filepath': 'images/5986.jpg', 'anomaly_class': 'Cell'},
#  '5987': {'image_filepath': 'images/5987.jpg', 'anomaly_class': 'Cell'},
#  '5984': {'image_filepath': 'images/5984.jpg', 'anomaly_class': 'Cell'},
#  '5985': {'image_filepath': 'images/5985.jpg', 'anomaly_class': 'Cell'},
#  '12441': {'image_filepath': 'images/12441.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '19713': {'image_filepath': 'images/19713.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '14544': {'image_filepath': 'images/14544.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '15267': {'image_filepath': 'images/15267.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '19711': {'image_filepath': 'images/19711.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '18516': {'image_filepath': 'images/18516.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '16070': {'image_filepath': 'images/16070.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '19717': {'image_filepath': 'images/19717.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '19716': {'image_filepath': 'images/19716.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '16075': {'image_filepath': 'images/16075.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '18441': {'image_filepath': 'images/18441.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '16074': {'image_filepath': 'images/16074.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '6796': {'image_filepath': 'images/6796.jpg', 'anomaly_class': 'Hot-Spot'},
#  '6797': {'image_filepath': 'images/6797.jpg', 'anomaly_class': 'Hot-Spot'},
#  '6794': {'image_filepath': 'images/6794.jpg', 'anomaly_class': 'Hot-Spot'},
#  '6795': {'image_filepath': 'images/6795.jpg', 'anomaly_class': 'Hot-Spot'},
#  '6792': {'image_filepath': 'images/6792.jpg', 'anomaly_class': 'Hot-Spot'},
#  '6793': {'image_filepath': 'images/6793.jpg', 'anomaly_class': 'Hot-Spot'},
#  '6790': {'image_filepath': 'images/6790.jpg', 'anomaly_class': 'Hot-Spot'},
#  '6791': {'image_filepath': 'images/6791.jpg', 'anomaly_class': 'Hot-Spot'},
#  '13637': {'image_filepath': 'images/13637.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '16642': {'image_filepath': 'images/16642.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '6798': {'image_filepath': 'images/6798.jpg', 'anomaly_class': 'Hot-Spot'},
#  '6799': {'image_filepath': 'images/6799.jpg', 'anomaly_class': 'Hot-Spot'},
#  '13549': {'image_filepath': 'images/13549.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '19071': {'image_filepath': 'images/19071.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '6294': {'image_filepath': 'images/6294.jpg', 'anomaly_class': 'Cell'},
#  '18362': {'image_filepath': 'images/18362.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '270': {'image_filepath': 'images/270.jpg',
#   'anomaly_class': 'Offline-Module'},
#  '271': {'image_filepath': 'images/271.jpg',
#   'anomaly_class': 'Offline-Module'},
#  '272': {'image_filepath': 'images/272.jpg',
#   'anomaly_class': 'Offline-Module'},
#  '273': {'image_filepath': 'images/273.jpg',
#   'anomaly_class': 'Offline-Module'},
#  '274': {'image_filepath': 'images/274.jpg',
#   'anomaly_class': 'Offline-Module'},
#  '275': {'image_filepath': 'images/275.jpg',
#   'anomaly_class': 'Offline-Module'},
#  '276': {'image_filepath': 'images/276.jpg',
#   'anomaly_class': 'Offline-Module'},
#  '277': {'image_filepath': 'images/277.jpg',
#   'anomaly_class': 'Offline-Module'},
#  '278': {'image_filepath': 'images/278.jpg',
#   'anomaly_class': 'Offline-Module'},
#  '279': {'image_filepath': 'images/279.jpg',
#   'anomaly_class': 'Offline-Module'},
#  '16259': {'image_filepath': 'images/16259.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '16258': {'image_filepath': 'images/16258.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '16701': {'image_filepath': 'images/16701.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '16700': {'image_filepath': 'images/16700.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '16703': {'image_filepath': 'images/16703.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '16702': {'image_filepath': 'images/16702.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '12019': {'image_filepath': 'images/12019.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '12018': {'image_filepath': 'images/12018.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '12015': {'image_filepath': 'images/12015.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '12014': {'image_filepath': 'images/12014.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '12017': {'image_filepath': 'images/12017.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '12016': {'image_filepath': 'images/12016.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '12011': {'image_filepath': 'images/12011.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '12010': {'image_filepath': 'images/12010.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '12013': {'image_filepath': 'images/12013.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '12012': {'image_filepath': 'images/12012.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '17258': {'image_filepath': 'images/17258.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '15369': {'image_filepath': 'images/15369.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '15950': {'image_filepath': 'images/15950.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '17250': {'image_filepath': 'images/17250.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '17251': {'image_filepath': 'images/17251.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '17252': {'image_filepath': 'images/17252.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '17253': {'image_filepath': 'images/17253.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '17254': {'image_filepath': 'images/17254.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '15953': {'image_filepath': 'images/15953.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '17256': {'image_filepath': 'images/17256.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '17257': {'image_filepath': 'images/17257.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '10709': {'image_filepath': 'images/10709.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '10708': {'image_filepath': 'images/10708.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '9528': {'image_filepath': 'images/9528.jpg', 'anomaly_class': 'Vegetation'},
#  '9529': {'image_filepath': 'images/9529.jpg', 'anomaly_class': 'Vegetation'},
#  '9258': {'image_filepath': 'images/9258.jpg', 'anomaly_class': 'Vegetation'},
#  '9259': {'image_filepath': 'images/9259.jpg', 'anomaly_class': 'Vegetation'},
#  '9256': {'image_filepath': 'images/9256.jpg', 'anomaly_class': 'Vegetation'},
#  '9257': {'image_filepath': 'images/9257.jpg', 'anomaly_class': 'Vegetation'},
#  '9254': {'image_filepath': 'images/9254.jpg', 'anomaly_class': 'Vegetation'},
#  '9255': {'image_filepath': 'images/9255.jpg', 'anomaly_class': 'Vegetation'},
#  '9252': {'image_filepath': 'images/9252.jpg', 'anomaly_class': 'Vegetation'},
#  '9253': {'image_filepath': 'images/9253.jpg', 'anomaly_class': 'Vegetation'},
#  '9250': {'image_filepath': 'images/9250.jpg', 'anomaly_class': 'Vegetation'},
#  '9251': {'image_filepath': 'images/9251.jpg', 'anomaly_class': 'Vegetation'},
#  '16833': {'image_filepath': 'images/16833.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '15957': {'image_filepath': 'images/15957.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '18517': {'image_filepath': 'images/18517.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '15956': {'image_filepath': 'images/15956.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '17577': {'image_filepath': 'images/17577.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '17301': {'image_filepath': 'images/17301.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '19957': {'image_filepath': 'images/19957.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '19397': {'image_filepath': 'images/19397.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '19396': {'image_filepath': 'images/19396.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '10619': {'image_filepath': 'images/10619.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '19395': {'image_filepath': 'images/19395.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '2143': {'image_filepath': 'images/2143.jpg', 'anomaly_class': 'Diode'},
#  '19394': {'image_filepath': 'images/19394.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '16381': {'image_filepath': 'images/16381.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '19305': {'image_filepath': 'images/19305.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '19393': {'image_filepath': 'images/19393.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '19392': {'image_filepath': 'images/19392.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '19391': {'image_filepath': 'images/19391.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '10618': {'image_filepath': 'images/10618.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '19390': {'image_filepath': 'images/19390.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '14729': {'image_filepath': 'images/14729.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '2142': {'image_filepath': 'images/2142.jpg', 'anomaly_class': 'Diode'},
#  '3519': {'image_filepath': 'images/3519.jpg', 'anomaly_class': 'Shadowing'},
#  '3518': {'image_filepath': 'images/3518.jpg', 'anomaly_class': 'Shadowing'},
#  '3513': {'image_filepath': 'images/3513.jpg', 'anomaly_class': 'Shadowing'},
#  '3512': {'image_filepath': 'images/3512.jpg', 'anomaly_class': 'Shadowing'},
#  '3511': {'image_filepath': 'images/3511.jpg', 'anomaly_class': 'Shadowing'},
#  '3510': {'image_filepath': 'images/3510.jpg', 'anomaly_class': 'Shadowing'},
#  '3517': {'image_filepath': 'images/3517.jpg', 'anomaly_class': 'Shadowing'},
#  '3516': {'image_filepath': 'images/3516.jpg', 'anomaly_class': 'Shadowing'},
#  '3515': {'image_filepath': 'images/3515.jpg', 'anomaly_class': 'Shadowing'},
#  '3514': {'image_filepath': 'images/3514.jpg', 'anomaly_class': 'Shadowing'},
#  '17519': {'image_filepath': 'images/17519.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '2688': {'image_filepath': 'images/2688.jpg', 'anomaly_class': 'Shadowing'},
#  '2689': {'image_filepath': 'images/2689.jpg', 'anomaly_class': 'Shadowing'},
#  '2684': {'image_filepath': 'images/2684.jpg', 'anomaly_class': 'Shadowing'},
#  '2685': {'image_filepath': 'images/2685.jpg', 'anomaly_class': 'Shadowing'},
#  '2686': {'image_filepath': 'images/2686.jpg', 'anomaly_class': 'Shadowing'},
#  '2687': {'image_filepath': 'images/2687.jpg', 'anomaly_class': 'Shadowing'},
#  '2680': {'image_filepath': 'images/2680.jpg', 'anomaly_class': 'Shadowing'},
#  '2681': {'image_filepath': 'images/2681.jpg', 'anomaly_class': 'Shadowing'},
#  '2682': {'image_filepath': 'images/2682.jpg', 'anomaly_class': 'Shadowing'},
#  '2683': {'image_filepath': 'images/2683.jpg', 'anomaly_class': 'Shadowing'},
#  '14624': {'image_filepath': 'images/14624.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '14625': {'image_filepath': 'images/14625.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '13440': {'image_filepath': 'images/13440.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '14474': {'image_filepath': 'images/14474.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '14620': {'image_filepath': 'images/14620.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '14621': {'image_filepath': 'images/14621.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '14622': {'image_filepath': 'images/14622.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '14623': {'image_filepath': 'images/14623.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '16768': {'image_filepath': 'images/16768.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '14628': {'image_filepath': 'images/14628.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '14629': {'image_filepath': 'images/14629.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '99': {'image_filepath': 'images/99.jpg', 'anomaly_class': 'Offline-Module'},
#  '98': {'image_filepath': 'images/98.jpg', 'anomaly_class': 'Offline-Module'},
#  '18334': {'image_filepath': 'images/18334.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '11362': {'image_filepath': 'images/11362.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '91': {'image_filepath': 'images/91.jpg', 'anomaly_class': 'Offline-Module'},
#  '90': {'image_filepath': 'images/90.jpg', 'anomaly_class': 'Offline-Module'},
#  '93': {'image_filepath': 'images/93.jpg', 'anomaly_class': 'Offline-Module'},
#  '92': {'image_filepath': 'images/92.jpg', 'anomaly_class': 'Offline-Module'},
#  '95': {'image_filepath': 'images/95.jpg', 'anomaly_class': 'Offline-Module'},
#  '94': {'image_filepath': 'images/94.jpg', 'anomaly_class': 'Offline-Module'},
#  '97': {'image_filepath': 'images/97.jpg', 'anomaly_class': 'Offline-Module'},
#  '96': {'image_filepath': 'images/96.jpg', 'anomaly_class': 'Offline-Module'},
#  '15490': {'image_filepath': 'images/15490.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '14607': {'image_filepath': 'images/14607.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '15363': {'image_filepath': 'images/15363.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '18514': {'image_filepath': 'images/18514.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '13058': {'image_filepath': 'images/13058.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '13059': {'image_filepath': 'images/13059.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '16235': {'image_filepath': 'images/16235.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '13052': {'image_filepath': 'images/13052.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '13053': {'image_filepath': 'images/13053.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '13050': {'image_filepath': 'images/13050.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '13051': {'image_filepath': 'images/13051.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '13056': {'image_filepath': 'images/13056.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '13057': {'image_filepath': 'images/13057.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '13054': {'image_filepath': 'images/13054.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '13055': {'image_filepath': 'images/13055.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '18703': {'image_filepath': 'images/18703.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '11664': {'image_filepath': 'images/11664.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '18701': {'image_filepath': 'images/18701.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '15360': {'image_filepath': 'images/15360.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '13912': {'image_filepath': 'images/13912.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '18706': {'image_filepath': 'images/18706.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '18705': {'image_filepath': 'images/18705.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '18704': {'image_filepath': 'images/18704.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '17995': {'image_filepath': 'images/17995.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '18709': {'image_filepath': 'images/18709.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '18708': {'image_filepath': 'images/18708.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '19647': {'image_filepath': 'images/19647.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '15249': {'image_filepath': 'images/15249.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '15080': {'image_filepath': 'images/15080.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '12109': {'image_filepath': 'images/12109.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '17829': {'image_filepath': 'images/17829.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '17828': {'image_filepath': 'images/17828.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '12643': {'image_filepath': 'images/12643.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '17826': {'image_filepath': 'images/17826.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '17825': {'image_filepath': 'images/17825.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '17824': {'image_filepath': 'images/17824.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '17823': {'image_filepath': 'images/17823.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '17822': {'image_filepath': 'images/17822.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '17821': {'image_filepath': 'images/17821.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '17820': {'image_filepath': 'images/17820.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '18432': {'image_filepath': 'images/18432.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '15361': {'image_filepath': 'images/15361.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '14964': {'image_filepath': 'images/14964.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '16882': {'image_filepath': 'images/16882.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '16237': {'image_filepath': 'images/16237.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '18278': {'image_filepath': 'images/18278.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '10693': {'image_filepath': 'images/10693.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '15366': {'image_filepath': 'images/15366.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '1177': {'image_filepath': 'images/1177.jpg', 'anomaly_class': 'Diode'},
#  '1176': {'image_filepath': 'images/1176.jpg', 'anomaly_class': 'Diode'},
#  '1175': {'image_filepath': 'images/1175.jpg', 'anomaly_class': 'Diode'},
#  '1174': {'image_filepath': 'images/1174.jpg', 'anomaly_class': 'Diode'},
#  '1173': {'image_filepath': 'images/1173.jpg', 'anomaly_class': 'Diode'},
#  '1172': {'image_filepath': 'images/1172.jpg', 'anomaly_class': 'Diode'},
#  '1171': {'image_filepath': 'images/1171.jpg', 'anomaly_class': 'Diode'},
#  '1170': {'image_filepath': 'images/1170.jpg', 'anomaly_class': 'Diode'},
#  '17966': {'image_filepath': 'images/17966.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '1179': {'image_filepath': 'images/1179.jpg', 'anomaly_class': 'Diode'},
#  '1178': {'image_filepath': 'images/1178.jpg', 'anomaly_class': 'Diode'},
#  '10580': {'image_filepath': 'images/10580.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '19851': {'image_filepath': 'images/19851.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '16379': {'image_filepath': 'images/16379.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '15367': {'image_filepath': 'images/15367.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '19330': {'image_filepath': 'images/19330.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '16890': {'image_filepath': 'images/16890.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '17595': {'image_filepath': 'images/17595.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '17755': {'image_filepath': 'images/17755.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '17594': {'image_filepath': 'images/17594.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '11771': {'image_filepath': 'images/11771.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '7188': {'image_filepath': 'images/7188.jpg', 'anomaly_class': 'Cracking'},
#  '876': {'image_filepath': 'images/876.jpg', 'anomaly_class': 'Diode-Multi'},
#  '15066': {'image_filepath': 'images/15066.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '877': {'image_filepath': 'images/877.jpg', 'anomaly_class': 'Diode-Multi'},
#  '7180': {'image_filepath': 'images/7180.jpg', 'anomaly_class': 'Cracking'},
#  '7181': {'image_filepath': 'images/7181.jpg', 'anomaly_class': 'Cracking'},
#  '7182': {'image_filepath': 'images/7182.jpg', 'anomaly_class': 'Cracking'},
#  '7183': {'image_filepath': 'images/7183.jpg', 'anomaly_class': 'Cracking'},
#  '7184': {'image_filepath': 'images/7184.jpg', 'anomaly_class': 'Cracking'},
#  '3432': {'image_filepath': 'images/3432.jpg', 'anomaly_class': 'Shadowing'},
#  '7186': {'image_filepath': 'images/7186.jpg', 'anomaly_class': 'Cracking'},
#  '7187': {'image_filepath': 'images/7187.jpg', 'anomaly_class': 'Cracking'},
#  '623': {'image_filepath': 'images/623.jpg',
#   'anomaly_class': 'Offline-Module'},
#  '15281': {'image_filepath': 'images/15281.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '875': {'image_filepath': 'images/875.jpg', 'anomaly_class': 'Diode-Multi'},
#  '18515': {'image_filepath': 'images/18515.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '17754': {'image_filepath': 'images/17754.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '622': {'image_filepath': 'images/622.jpg',
#   'anomaly_class': 'Offline-Module'},
#  '872': {'image_filepath': 'images/872.jpg', 'anomaly_class': 'Diode-Multi'},
#  '1225': {'image_filepath': 'images/1225.jpg', 'anomaly_class': 'Diode'},
#  '3435': {'image_filepath': 'images/3435.jpg', 'anomaly_class': 'Shadowing'},
#  '12833': {'image_filepath': 'images/12833.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '12832': {'image_filepath': 'images/12832.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '12831': {'image_filepath': 'images/12831.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '620': {'image_filepath': 'images/620.jpg',
#   'anomaly_class': 'Offline-Module'},
#  '8549': {'image_filepath': 'images/8549.jpg', 'anomaly_class': 'Vegetation'},
#  '870': {'image_filepath': 'images/870.jpg', 'anomaly_class': 'Diode-Multi'},
#  '8019': {'image_filepath': 'images/8019.jpg',
#   'anomaly_class': 'Hot-Spot-Multi'},
#  '8018': {'image_filepath': 'images/8018.jpg',
#   'anomaly_class': 'Hot-Spot-Multi'},
#  '8017': {'image_filepath': 'images/8017.jpg',
#   'anomaly_class': 'Hot-Spot-Multi'},
#  '627': {'image_filepath': 'images/627.jpg',
#   'anomaly_class': 'Offline-Module'},
#  '8015': {'image_filepath': 'images/8015.jpg',
#   'anomaly_class': 'Hot-Spot-Multi'},
#  '871': {'image_filepath': 'images/871.jpg', 'anomaly_class': 'Diode-Multi'},
#  '8013': {'image_filepath': 'images/8013.jpg',
#   'anomaly_class': 'Hot-Spot-Multi'},
#  '8012': {'image_filepath': 'images/8012.jpg',
#   'anomaly_class': 'Hot-Spot-Multi'},
#  '8011': {'image_filepath': 'images/8011.jpg',
#   'anomaly_class': 'Hot-Spot-Multi'},
#  '626': {'image_filepath': 'images/626.jpg',
#   'anomaly_class': 'Offline-Module'},
#  '7456': {'image_filepath': 'images/7456.jpg', 'anomaly_class': 'Cracking'},
#  '4592': {'image_filepath': 'images/4592.jpg', 'anomaly_class': 'Cell-Multi'},
#  '7454': {'image_filepath': 'images/7454.jpg', 'anomaly_class': 'Cracking'},
#  '7455': {'image_filepath': 'images/7455.jpg', 'anomaly_class': 'Cracking'},
#  '7452': {'image_filepath': 'images/7452.jpg', 'anomaly_class': 'Cracking'},
#  '625': {'image_filepath': 'images/625.jpg',
#   'anomaly_class': 'Offline-Module'},
#  '7450': {'image_filepath': 'images/7450.jpg', 'anomaly_class': 'Cracking'},
#  '2036': {'image_filepath': 'images/2036.jpg', 'anomaly_class': 'Diode'},
#  '624': {'image_filepath': 'images/624.jpg',
#   'anomaly_class': 'Offline-Module'},
#  '4590': {'image_filepath': 'images/4590.jpg', 'anomaly_class': 'Cell-Multi'},
#  '7458': {'image_filepath': 'images/7458.jpg', 'anomaly_class': 'Cracking'},
#  '7459': {'image_filepath': 'images/7459.jpg', 'anomaly_class': 'Cracking'},
#  '19906': {'image_filepath': 'images/19906.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '4591': {'image_filepath': 'images/4591.jpg', 'anomaly_class': 'Cell-Multi'},
#  '19335': {'image_filepath': 'images/19335.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '4596': {'image_filepath': 'images/4596.jpg', 'anomaly_class': 'Cell-Multi'},
#  '4849': {'image_filepath': 'images/4849.jpg', 'anomaly_class': 'Cell'},
#  '13603': {'image_filepath': 'images/13603.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '4594': {'image_filepath': 'images/4594.jpg', 'anomaly_class': 'Cell-Multi'},
#  '13602': {'image_filepath': 'images/13602.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '4595': {'image_filepath': 'images/4595.jpg', 'anomaly_class': 'Cell-Multi'},
#  '13601': {'image_filepath': 'images/13601.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '10884': {'image_filepath': 'images/10884.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '2749': {'image_filepath': 'images/2749.jpg', 'anomaly_class': 'Shadowing'},
#  '10886': {'image_filepath': 'images/10886.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '10887': {'image_filepath': 'images/10887.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '10880': {'image_filepath': 'images/10880.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '10881': {'image_filepath': 'images/10881.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '10882': {'image_filepath': 'images/10882.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '4845': {'image_filepath': 'images/4845.jpg', 'anomaly_class': 'Cell'},
#  '13607': {'image_filepath': 'images/13607.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '10888': {'image_filepath': 'images/10888.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '4598': {'image_filepath': 'images/4598.jpg', 'anomaly_class': 'Cell-Multi'},
#  '12877': {'image_filepath': 'images/12877.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '13606': {'image_filepath': 'images/13606.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '14464': {'image_filepath': 'images/14464.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '8291': {'image_filepath': 'images/8291.jpg', 'anomaly_class': 'Soiling'},
#  '4599': {'image_filepath': 'images/4599.jpg', 'anomaly_class': 'Cell-Multi'},
#  '4734': {'image_filepath': 'images/4734.jpg', 'anomaly_class': 'Cell-Multi'},
#  '8290': {'image_filepath': 'images/8290.jpg', 'anomaly_class': 'Soiling'},
#  '19760': {'image_filepath': 'images/19760.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '4735': {'image_filepath': 'images/4735.jpg', 'anomaly_class': 'Cell-Multi'},
#  '8293': {'image_filepath': 'images/8293.jpg', 'anomaly_class': 'Soiling'},
#  '14476': {'image_filepath': 'images/14476.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '8292': {'image_filepath': 'images/8292.jpg', 'anomaly_class': 'Soiling'},
#  '2039': {'image_filepath': 'images/2039.jpg', 'anomaly_class': 'Diode'},
#  '8295': {'image_filepath': 'images/8295.jpg', 'anomaly_class': 'Soiling'},
#  '4843': {'image_filepath': 'images/4843.jpg', 'anomaly_class': 'Cell-Multi'},
#  '12876': {'image_filepath': 'images/12876.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '4738': {'image_filepath': 'images/4738.jpg', 'anomaly_class': 'Cell-Multi'},
#  '16433': {'image_filepath': 'images/16433.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '8294': {'image_filepath': 'images/8294.jpg', 'anomaly_class': 'Soiling'},
#  '4739': {'image_filepath': 'images/4739.jpg', 'anomaly_class': 'Cell-Multi'},
#  '8297': {'image_filepath': 'images/8297.jpg', 'anomaly_class': 'Soiling'},
#  '8296': {'image_filepath': 'images/8296.jpg', 'anomaly_class': 'Soiling'},
#  '393': {'image_filepath': 'images/393.jpg',
#   'anomaly_class': 'Offline-Module'},
#  '392': {'image_filepath': 'images/392.jpg',
#   'anomaly_class': 'Offline-Module'},
#  '391': {'image_filepath': 'images/391.jpg',
#   'anomaly_class': 'Offline-Module'},
#  '390': {'image_filepath': 'images/390.jpg',
#   'anomaly_class': 'Offline-Module'},
#  '397': {'image_filepath': 'images/397.jpg',
#   'anomaly_class': 'Offline-Module'},
#  '396': {'image_filepath': 'images/396.jpg',
#   'anomaly_class': 'Offline-Module'},
#  '395': {'image_filepath': 'images/395.jpg',
#   'anomaly_class': 'Offline-Module'},
#  '394': {'image_filepath': 'images/394.jpg',
#   'anomaly_class': 'Offline-Module'},
#  '399': {'image_filepath': 'images/399.jpg',
#   'anomaly_class': 'Offline-Module'},
#  '398': {'image_filepath': 'images/398.jpg',
#   'anomaly_class': 'Offline-Module'},
#  '19279': {'image_filepath': 'images/19279.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '2309': {'image_filepath': 'images/2309.jpg', 'anomaly_class': 'Diode'},
#  '2308': {'image_filepath': 'images/2308.jpg', 'anomaly_class': 'Diode'},
#  '4729': {'image_filepath': 'images/4729.jpg', 'anomaly_class': 'Cell-Multi'},
#  '4728': {'image_filepath': 'images/4728.jpg', 'anomaly_class': 'Cell-Multi'},
#  '2301': {'image_filepath': 'images/2301.jpg', 'anomaly_class': 'Diode'},
#  '2300': {'image_filepath': 'images/2300.jpg', 'anomaly_class': 'Diode'},
#  '2303': {'image_filepath': 'images/2303.jpg', 'anomaly_class': 'Diode'},
#  '2302': {'image_filepath': 'images/2302.jpg', 'anomaly_class': 'Diode'},
#  '2305': {'image_filepath': 'images/2305.jpg', 'anomaly_class': 'Diode'},
#  '2304': {'image_filepath': 'images/2304.jpg', 'anomaly_class': 'Diode'},
#  '2307': {'image_filepath': 'images/2307.jpg', 'anomaly_class': 'Diode'},
#  '2306': {'image_filepath': 'images/2306.jpg', 'anomaly_class': 'Diode'},
#  '5847': {'image_filepath': 'images/5847.jpg', 'anomaly_class': 'Cell'},
#  '5846': {'image_filepath': 'images/5846.jpg', 'anomaly_class': 'Cell'},
#  '5845': {'image_filepath': 'images/5845.jpg', 'anomaly_class': 'Cell'},
#  '5844': {'image_filepath': 'images/5844.jpg', 'anomaly_class': 'Cell'},
#  '5843': {'image_filepath': 'images/5843.jpg', 'anomaly_class': 'Cell'},
#  '5842': {'image_filepath': 'images/5842.jpg', 'anomaly_class': 'Cell'},
#  '5841': {'image_filepath': 'images/5841.jpg', 'anomaly_class': 'Cell'},
#  '5840': {'image_filepath': 'images/5840.jpg', 'anomaly_class': 'Cell'},
#  '11281': {'image_filepath': 'images/11281.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '11280': {'image_filepath': 'images/11280.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '11283': {'image_filepath': 'images/11283.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '11282': {'image_filepath': 'images/11282.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '11285': {'image_filepath': 'images/11285.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '11284': {'image_filepath': 'images/11284.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '5849': {'image_filepath': 'images/5849.jpg', 'anomaly_class': 'Cell'},
#  '5848': {'image_filepath': 'images/5848.jpg', 'anomaly_class': 'Cell'},
#  '17621': {'image_filepath': 'images/17621.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '14727': {'image_filepath': 'images/14727.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '16558': {'image_filepath': 'images/16558.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '17622': {'image_filepath': 'images/17622.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '17625': {'image_filepath': 'images/17625.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '17624': {'image_filepath': 'images/17624.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '3748': {'image_filepath': 'images/3748.jpg', 'anomaly_class': 'Cell-Multi'},
#  '3749': {'image_filepath': 'images/3749.jpg', 'anomaly_class': 'Cell-Multi'},
#  '3746': {'image_filepath': 'images/3746.jpg', 'anomaly_class': 'Cell-Multi'},
#  '3747': {'image_filepath': 'images/3747.jpg', 'anomaly_class': 'Cell-Multi'},
#  '3744': {'image_filepath': 'images/3744.jpg', 'anomaly_class': 'Cell-Multi'},
#  '3745': {'image_filepath': 'images/3745.jpg', 'anomaly_class': 'Cell-Multi'},
#  '3742': {'image_filepath': 'images/3742.jpg', 'anomaly_class': 'Cell-Multi'},
#  '3743': {'image_filepath': 'images/3743.jpg', 'anomaly_class': 'Cell-Multi'},
#  '3740': {'image_filepath': 'images/3740.jpg', 'anomaly_class': 'Cell-Multi'},
#  '3741': {'image_filepath': 'images/3741.jpg', 'anomaly_class': 'Cell-Multi'},
#  '4620': {'image_filepath': 'images/4620.jpg', 'anomaly_class': 'Cell-Multi'},
#  '4621': {'image_filepath': 'images/4621.jpg', 'anomaly_class': 'Cell-Multi'},
#  '4622': {'image_filepath': 'images/4622.jpg', 'anomaly_class': 'Cell-Multi'},
#  '4623': {'image_filepath': 'images/4623.jpg', 'anomaly_class': 'Cell-Multi'},
#  '4624': {'image_filepath': 'images/4624.jpg', 'anomaly_class': 'Cell-Multi'},
#  '4625': {'image_filepath': 'images/4625.jpg', 'anomaly_class': 'Cell-Multi'},
#  '4626': {'image_filepath': 'images/4626.jpg', 'anomaly_class': 'Cell-Multi'},
#  '4627': {'image_filepath': 'images/4627.jpg', 'anomaly_class': 'Cell-Multi'},
#  '4628': {'image_filepath': 'images/4628.jpg', 'anomaly_class': 'Cell-Multi'},
#  '4629': {'image_filepath': 'images/4629.jpg', 'anomaly_class': 'Cell-Multi'},
#  '12778': {'image_filepath': 'images/12778.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '14539': {'image_filepath': 'images/14539.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '11757': {'image_filepath': 'images/11757.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '11756': {'image_filepath': 'images/11756.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '11755': {'image_filepath': 'images/11755.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '11754': {'image_filepath': 'images/11754.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '11753': {'image_filepath': 'images/11753.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '11752': {'image_filepath': 'images/11752.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '11751': {'image_filepath': 'images/11751.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '10467': {'image_filepath': 'images/10467.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '10695': {'image_filepath': 'images/10695.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '14409': {'image_filepath': 'images/14409.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '19500': {'image_filepath': 'images/19500.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '14169': {'image_filepath': 'images/14169.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '11759': {'image_filepath': 'images/11759.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '11758': {'image_filepath': 'images/11758.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '16392': {'image_filepath': 'images/16392.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '14534': {'image_filepath': 'images/14534.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '
jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '7210': {'image_filepath': 'images/7210.jpg', 'anomaly_class': 'Cracking'},
#  '7211': {'image_filepath': 'images/7211.jpg', 'anomaly_class': 'Cracking'},
#  '7212': {'image_filepath': 'images/7212.jpg', 'anomaly_class': 'Cracking'},
#  '7213': {'image_filepath': 'images/7213.jpg', 'anomaly_class': 'Cracking'},
#  '7214': {'image_filepath': 'images/7214.jpg', 'anomaly_class': 'Cracking'},
#  '7215': {'image_filepath': 'images/7215.jpg', 'anomaly_class': 'Cracking'},
#  '7216': {'image_filepath': 'images/7216.jpg', 'anomaly_class': 'Cracking'},
#  '7217': {'image_filepath': 'images/7217.jpg', 'anomaly_class': 'Cracking'},
#  '6217': {'image_filepath': 'images/6217.jpg', 'anomaly_class': 'Cell'},
#  '6216': {'image_filepath': 'images/6216.jpg', 'anomaly_class': 'Cell'},
#  '6215': {'image_filepath': 'images/6215.jpg', 'anomaly_class': 'Cell'},
#  '6214': {'image_filepath': 'images/6214.jpg', 'anomaly_class': 'Cell'},
#  '6213': {'image_filepath': 'images/6213.jpg', 'anomaly_class': 'Cell'},
#  '6212': {'image_filepath': 'images/6212.jpg', 'anomaly_class': 'Cell'},
#  '6211': {'image_filepath': 'images/6211.jpg', 'anomaly_class': 'Cell'},
#  '6210': {'image_filepath': 'images/6210.jpg', 'anomaly_class': 'Cell'},
#  '13540': {'image_filepath': 'images/13540.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '6219': {'image_filepath': 'images/6219.jpg', 'anomaly_class': 'Cell'},
#  '6218': {'image_filepath': 'images/6218.jpg', 'anomaly_class': 'Cell'},
#  '6819': {'image_filepath': 'images/6819.jpg', 'anomaly_class': 'Hot-Spot'},
#  '6818': {'image_filepath': 'images/6818.jpg', 'anomaly_class': 'Hot-Spot'},
#  '18327': {'image_filepath': 'images/18327.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '13542': {'image_filepath': 'images/13542.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '15878': {'image_filepath': 'images/15878.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '15879': {'image_filepath': 'images/15879.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '6811': {'image_filepath': 'images/6811.jpg', 'anomaly_class': 'Hot-Spot'},
#  '6810': {'image_filepath': 'images/6810.jpg', 'anomaly_class': 'Hot-Spot'},
#  '6813': {'image_filepath': 'images/6813.jpg', 'anomaly_class': 'Hot-Spot'},
#  '6812': {'image_filepath': 'images/6812.jpg', 'anomaly_class': 'Hot-Spot'},
#  '6815': {'image_filepath': 'images/6815.jpg', 'anomaly_class': 'Hot-Spot'},
#  '6814': {'image_filepath': 'images/6814.jpg', 'anomaly_class': 'Hot-Spot'},
#  '6817': {'image_filepath': 'images/6817.jpg', 'anomaly_class': 'Hot-Spot'},
#  '6816': {'image_filepath': 'images/6816.jpg', 'anomaly_class': 'Hot-Spot'},
#  '9757': {'image_filepath': 'images/9757.jpg', 'anomaly_class': 'Vegetation'},
#  '9756': {'image_filepath': 'images/9756.jpg', 'anomaly_class': 'Vegetation'},
#  '9755': {'image_filepath': 'images/9755.jpg', 'anomaly_class': 'Vegetation'},
#  '9754': {'image_filepath': 'images/9754.jpg', 'anomaly_class': 'Vegetation'},
#  '9753': {'image_filepath': 'images/9753.jpg', 'anomaly_class': 'Vegetation'},
#  '9752': {'image_filepath': 'images/9752.jpg', 'anomaly_class': 'Vegetation'},
#  '9751': {'image_filepath': 'images/9751.jpg', 'anomaly_class': 'Vegetation'},
#  '9750': {'image_filepath': 'images/9750.jpg', 'anomaly_class': 'Vegetation'},
#  '10574': {'image_filepath': 'images/10574.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '10575': {'image_filepath': 'images/10575.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '10576': {'image_filepath': 'images/10576.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '10577': {'image_filepath': 'images/10577.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '10570': {'image_filepath': 'images/10570.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '10571': {'image_filepath': 'images/10571.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '9759': {'image_filepath': 'images/9759.jpg', 'anomaly_class': 'Vegetation'},
#  '9758': {'image_filepath': 'images/9758.jpg', 'anomaly_class': 'Vegetation'},
#  '18934': {'image_filepath': 'images/18934.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '18538': {'image_filepath': 'images/18538.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '18326': {'image_filepath': 'images/18326.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '16706': {'image_filepath': 'images/16706.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '16886': {'image_filepath': 'images/16886.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '18931': {'image_filepath': 'images/18931.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '18932': {'image_filepath': 'images/18932.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '8913': {'image_filepath': 'images/8913.jpg', 'anomaly_class': 'Vegetation'},
#  '13548': {'image_filepath': 'images/13548.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '18938': {'image_filepath': 'images/18938.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '18939': {'image_filepath': 'images/18939.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '18009': {'image_filepath': 'images/18009.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '11772': {'image_filepath': 'images/11772.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '8848': {'image_filepath': 'images/8848.jpg', 'anomaly_class': 'Vegetation'},
#  '8849': {'image_filepath': 'images/8849.jpg', 'anomaly_class': 'Vegetation'},
#  '8840': {'image_filepath': 'images/8840.jpg', 'anomaly_class': 'Vegetation'},
#  '8841': {'image_filepath': 'images/8841.jpg', 'anomaly_class': 'Vegetation'},
#  '8842': {'image_filepath': 'images/8842.jpg', 'anomaly_class': 'Vegetation'},
#  '8843': {'image_filepath': 'images/8843.jpg', 'anomaly_class': 'Vegetation'},
#  '8844': {'image_filepath': 'images/8844.jpg', 'anomaly_class': 'Vegetation'},
#  '8845': {'image_filepath': 'images/8845.jpg', 'anomaly_class': 'Vegetation'},
#  '8846': {'image_filepath': 'images/8846.jpg', 'anomaly_class': 'Vegetation'},
#  '8847': {'image_filepath': 'images/8847.jpg', 'anomaly_class': 'Vegetation'},
#  '17546': {'image_filepath': 'images/17546.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '16086': {'image_filepath': 'images/16086.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '13384': {'image_filepath': 'images/13384.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '11849': {'image_filepath': 'images/11849.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '17066': {'image_filepath': 'images/17066.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '16438': {'image_filepath': 'images/16438.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '19273': {'image_filepath': 'images/19273.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '8915': {'image_filepath': 'images/8915.jpg', 'anomaly_class': 'Vegetation'},
#  '7669': {'image_filepath': 'images/7669.jpg', 'anomaly_class': 'Cracking'},
#  '7668': {'image_filepath': 'images/7668.jpg', 'anomaly_class': 'Cracking'},
#  '16507': {'image_filepath': 'images/16507.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '11509': {'image_filepath': 'images/11509.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '15236': {'image_filepath': 'images/15236.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '12667': {'image_filepath': 'images/12667.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '7661': {'image_filepath': 'images/7661.jpg', 'anomaly_class': 'Cracking'},
#  '7660': {'image_filepath': 'images/7660.jpg', 'anomaly_class': 'Cracking'},
#  '7663': {'image_filepath': 'images/7663.jpg', 'anomaly_class': 'Cracking'},
#  '7662': {'image_filepath': 'images/7662.jpg', 'anomaly_class': 'Cracking'},
#  '7665': {'image_filepath': 'images/7665.jpg', 'anomaly_class': 'Cracking'},
#  '7664': {'image_filepath': 'images/7664.jpg', 'anomaly_class': 'Cracking'},
#  '7667': {'image_filepath': 'images/7667.jpg', 'anomaly_class': 'Cracking'},
#  '7666': {'image_filepath': 'images/7666.jpg', 'anomaly_class': 'Cracking'},
#  '11844': {'image_filepath': 'images/11844.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '14520': {'image_filepath': 'images/14520.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '18534': {'image_filepath': 'images/18534.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '11842': {'image_filepath': 'images/11842.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '16506': {'image_filepath': 'images/16506.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '1768': {'image_filepath': 'images/1768.jpg', 'anomaly_class': 'Diode'},
#  '1769': {'image_filepath': 'images/1769.jpg', 'anomaly_class': 'Diode'},
#  '12664': {'image_filepath': 'images/12664.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '1762': {'image_filepath': 'images/1762.jpg', 'anomaly_class': 'Diode'},
#  '1763': {'image_filepath': 'images/1763.jpg', 'anomaly_class': 'Diode'},
#  '1760': {'image_filepath': 'images/1760.jpg', 'anomaly_class': 'Diode'},
# ...
#  '2515': {'image_filepath': 'images/2515.jpg', 'anomaly_class': 'Shadowing'},
#  '2516': {'image_filepath': 'images/2516.jpg', 'anomaly_class': 'Shadowing'},
#  '2517': {'image_filepath': 'images/2517.jpg', 'anomaly_class': 'Shadowing'},
#  '2510': {'image_filepath': 'images/2510.jpg', 'anomaly_class': 'Shadowing'},
#  '2511': {'image_filepath': 'images/2511.jpg', 'anomaly_class': 'Shadowing'},
#  '2512': {'image_filepath': 'images/2512.jpg', 'anomaly_class': 'Shadowing'},
#  '2513': {'image_filepath': 'images/2513.jpg', 'anomaly_class': 'Shadowing'},
#  '16256': {'image_filepath': 'images/16256.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '18069': {'image_filepath': 'images/18069.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '19095': {'image_filepath': 'images/19095.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '11489': {'image_filepath': 'images/11489.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '16743': {'image_filepath': 'images/16743.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '3531': {'image_filepath': 'images/3531.jpg', 'anomaly_class': 'Shadowing'},
#  '3530': {'image_filepath': 'images/3530.jpg', 'anomaly_class': 'Shadowing'},
#  '3533': {'image_filepath': 'images/3533.jpg', 'anomaly_class': 'Shadowing'},
#  '3532': {'image_filepath': 'images/3532.jpg', 'anomaly_class': 'Shadowing'},
#  '3535': {'image_filepath': 'images/3535.jpg', 'anomaly_class': 'Shadowing'},
#  '3534': {'image_filepath': 'images/3534.jpg', 'anomaly_class': 'Shadowing'},
#  '3537': {'image_filepath': 'images/3537.jpg', 'anomaly_class': 'Shadowing'},
#  '3536': {'image_filepath': 'images/3536.jpg', 'anomaly_class': 'Shadowing'},
#  '5054': {'image_filepath': 'images/5054.jpg', 'anomaly_class': 'Cell'},
#  '3538': {'image_filepath': 'images/3538.jpg', 'anomaly_class': 'Shadowing'},
#  '5056': {'image_filepath': 'images/5056.jpg', 'anomaly_class': 'Cell'},
#  '5057': {'image_filepath': 'images/5057.jpg', 'anomaly_class': 'Cell'},
#  '5050': {'image_filepath': 'images/5050.jpg', 'anomaly_class': 'Cell'},
#  '5051': {'image_filepath': 'images/5051.jpg', 'anomaly_class': 'Cell'},
#  '5052': {'image_filepath': 'images/5052.jpg', 'anomaly_class': 'Cell'},
#  '5053': {'image_filepath': 'images/5053.jpg', 'anomaly_class': 'Cell'},
#  '19096': {'image_filepath': 'images/19096.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '15308': {'image_filepath': 'images/15308.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '16742': {'image_filepath': 'images/16742.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '10761': {'image_filepath': 'images/10761.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '10760': {'image_filepath': 'images/10760.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '10763': {'image_filepath': 'images/10763.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '10762': {'image_filepath': 'images/10762.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '10765': {'image_filepath': 'images/10765.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '10764': {'image_filepath': 'images/10764.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '10767': {'image_filepath': 'images/10767.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '10766': {'image_filepath': 'images/10766.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '10769': {'image_filepath': 'images/10769.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '10768': {'image_filepath': 'images/10768.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '
#  '1156': {'image_filepath': 'images/1156.jpg', 'anomaly_class': 'Diode'},
#  '1151': {'image_filepath': 'images/1151.jpg', 'anomaly_class': 'Diode'},
#  '1150': {'image_filepath': 'images/1150.jpg', 'anomaly_class': 'Diode'},
#  '1153': {'image_filepath': 'images/1153.jpg', 'anomaly_class': 'Diode'},
#  '1152': {'image_filepath': 'images/1152.jpg', 'anomaly_class': 'Diode'},
#  '15119': {'image_filepath': 'images/15119.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '15118': {'image_filepath': 'images/15118.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '15115': {'image_filepath': 'images/15115.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '15114': {'image_filepath': 'images/15114.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '15117': {'image_filepath': 'images/15117.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '13568': {'image_filepath': 'images/13568.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '14283': {'image_filepath': 'images/14283.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '15110': {'image_filepath': 'images/15110.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '15113': {'image_filepath': 'images/15113.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '14746': {'image_filepath': 'images/14746.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '19355': {'image_filepath': 'images/19355.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '19238': {'image_filepath': 'images/19238.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '14087': {'image_filepath': 'images/14087.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '15692': {'image_filepath': 'images/15692.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '17632': {'image_filepath': 'images/17632.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '13569': {'image_filepath': 'images/13569.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '15307': {'image_filepath': 'images/15307.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '19354': {'image_filepath': 'images/19354.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '8035': {'image_filepath': 'images/8035.jpg',
#   'anomaly_class': 'Hot-Spot-Multi'},
#  '8034': {'image_filepath': 'images/8034.jpg',
#   'anomaly_class': 'Hot-Spot-Multi'},
#  '8037': {'image_filepath': 'images/8037.jpg',
#   'anomaly_class': 'Hot-Spot-Multi'},
#  '8036': {'image_filepath': 'images/8036.jpg',
#   'anomaly_class': 'Hot-Spot-Multi'},
#  '8031': {'image_filepath': 'images/8031.jpg',
#   'anomaly_class': 'Hot-Spot-Multi'},
#  '8030': {'image_filepath': 'images/8030.jpg',
#   'anomaly_class': 'Hot-Spot-Multi'},
#  '8033': {'image_filepath': 'images/8033.jpg',
#   'anomaly_class': 'Hot-Spot-Multi'},
#  '8032': {'image_filepath': 'images/8032.jpg',
#   'anomaly_class': 'Hot-Spot-Multi'},
#  '17739': {'image_filepath': 'images/17739.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '15222': {'image_filepath': 'images/15222.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '8039': {'image_filepath': 'images/8039.jpg',
#   'anomaly_class': 'Hot-Spot-Multi'},
#  '8038': {'image_filepath': 'images/8038.jpg',
#   'anomaly_class': 'Hot-Spot-Multi'},
#  '15697': {'image_filepath': 'images/15697.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '12859': {'image_filepath': 'images/12859.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '12858': {'image_filepath': 'images/12858.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '8529': {'image_filepath': 'images/8529.jpg', 'anomaly_class': 'Vegetation'},
#  '8528': {'image_filepath': 'images/8528.jpg', 'anomaly_class': 'Vegetation'},
#  '15883': {'image_filepath': 'images/15883.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '13566': {'image_filepath': 'images/13566.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '8523': {'image_filepath': 'images/8523.jpg', 'anomaly_class': 'Vegetation'},
#  '8522': {'image_filepath': 'images/8522.jpg', 'anomaly_class': 'Vegetation'},
#  '8521': {'image_filepath': 'images/8521.jpg', 'anomaly_class': 'Vegetation'},
#  '8520': {'image_filepath': 'images/8520.jpg', 'anomaly_class': 'Vegetation'},
#  '8527': {'image_filepath': 'images/8527.jpg', 'anomaly_class': 'Vegetation'},
#  '8526': {'image_filepath': 'images/8526.jpg', 'anomaly_class': 'Vegetation'},
#  '8525': {'image_filepath': 'images/8525.jpg', 'anomaly_class': 'Vegetation'},
#  '8524': {'image_filepath': 'images/8524.jpg', 'anomaly_class': 'Vegetation'},
#  '16942': {'image_filepath': 'images/16942.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '18205': {'image_filepath': 'images/18205.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '19577': {'image_filepath': 'images/19577.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '8536': {'image_filepath': 'images/8536.jpg', 'anomaly_class': 'Vegetation'},
#  '10623': {'image_filepath': 'images/10623.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '17473': {'image_filepath': 'images/17473.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '15301': {'image_filepath': 'images/15301.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '10431': {'image_filepath': 'images/10431.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '10388': {'image_filepath': 'images/10388.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '18343': {'image_filepath': 'images/18343.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '12418': {'image_filepath': 'images/12418.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '14758': {'image_filepath': 'images/14758.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '19576': {'image_filepath': 'images/19576.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '12104': {'image_filepath': 'images/12104.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '13564': {'image_filepath': 'images/13564.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '13594': {'image_filepath': 'images/13594.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '15302': {'image_filepath': 'images/15302.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '10430': {'image_filepath': 'images/10430.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '16921': {'image_filepath': 'images/16921.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '18342': {'image_filepath': 'images/18342.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '16920': {'image_filepath': 'images/16920.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '4299': {'image_filepath': 'images/4299.jpg', 'anomaly_class': 'Cell-Multi'},
#  '4298': {'image_filepath': 'images/4298.jpg', 'anomaly_class': 'Cell-Multi'},
#  '10169': {'image_filepath': 'images/10169.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '19575': {'image_filepath': 'images/19575.jpg',
#   'anomaly_class': 'No-Anomaly'},
#  '4295': {'image_filepath': 'images/4295.jpg', 'anomaly_class': 'Cell-Multi'},
#  '4294': {'image_filepath': 'images/4294.jpg', 'anomaly_class': 'Cell-Multi'},
#  '4297': {'image_filepath': 'images/4297.jpg', 'anomaly_class': 'Cell-Multi'},
#  '4296': {'image_filepath': 'images/4296.jpg', 'anomaly_class': 'Cell-Multi'},
#  ...}

# %%
import os
import random
import json
import matplotlib.pyplot as plt

def view_images(image_dir, rows = 2, cols = 5, num_images = 10):
  """
  Views a random sample of images from a directory along with their anomaly class.

  Args:
    image_dir: The directory containing the images.
    num_images: The number of images to view.
  """
  # Load JSON data with anomaly classes
  json_file_path = json_path

  with open(json_file_path, 'r') as json_file:
    python_data = json.load(json_file)

  # Select random images
  image_files = [f for f in os.listdir(image_dir) if f.endswith('.jpg')]
  random_image_files = random.sample(image_files, min(num_images, len(image_files)))

  plt.figure(figsize=(15, 10))

  for i, image_file in enumerate(random_image_files):
    img_path = os.path.join(image_dir, image_file)
    img = plt.imread(img_path)

    # Extract anomaly class from JSON data
    image_filename = os.path.splitext(image_file)[0]  # Remove file extension
    anomaly_class = python_data.get(image_filename, {}).get('anomaly_class', 'Unknown')  # Get anomaly class, default to 'Unknown'

    plt.subplot(rows, cols, i + 1)
    plt.imshow(img)
    plt.title(f"Anomaly Class: {anomaly_class}")  # Title for each image
    plt.axis('off')

  plt.tight_layout()
  plt.show()

# Example usage
view_images(image_dir=image_path)

# %%
import os
import random
import json
import matplotlib.pyplot as plt
import tensorflow as tf

def view_images(image_dir, num_images=10, rows = 2, cols = 5):
  """
  Views a random sample of images from a directory along with their anomaly class, resizing them to 640x640.

  Args:
    image_dir: The directory containing the images.
    num_images: The number of images to view.
  """
  # Load JSON data with anomaly classes
  json_file_path = json_path

  with open(json_file_path, 'r') as json_file:
    python_data = json.load(json_file)

  # Select random images
  image_files = [f for f in os.listdir(image_dir) if f.endswith('.jpg')]
  random_image_files = random.sample(image_files, min(num_images, len(image_files)))

  plt.figure(figsize=(15, 10))

  for i, image_file in enumerate(random_image_files):
    img_path = os.path.join(image_dir, image_file)

    # Read the image
    img = tf.io.read_file(img_path)
    img = tf.image.decode_jpeg(img, channels=3)

    # Resize the image to 640x640
    img = tf.image.resize(img, [224, 224])

    # Convert back to numpy for plotting
    img = img.numpy().astype("uint8")

    # Extract anomaly class from JSON data
    image_filename = os.path.splitext(image_file)[0]  # Remove file extension
    anomaly_class = python_data.get(image_filename, {}).get('anomaly_class', 'Unknown')  # Get anomaly class, default to 'Unknown'

    plt.subplot(rows, cols, i + 1)
    plt.imshow(img)
    plt.title(f"Anomaly Class: {anomaly_class}")  # Title for each image
    plt.axis('off')

  plt.tight_layout()
  plt.show()

# Example usage
view_images(image_dir=image_path)

# %% [markdown]
# ## 3.0 Data Preprocessing

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 📦 Preprocessing & Dataset Pipeline

# %%
import os
import json
import tensorflow as tf
from sklearn.model_selection import train_test_split

# 1. Load metadata
with open(json_path, 'r') as f:
  metadata = json.load(f)

# 2. Create class-to-index mapping
classes = sorted({v['anomaly_class'] for v in metadata.values()})
class_to_idx = {cls: i for i, cls in enumerate(classes)}
print(f"Classes found: {class_to_idx}")

# # 3. Preprocessing function (resize + normalize)
# def preprocess_image(image):

#   image = tf.image.resize(image, [224, 224])
#   image = image / 255.0

#   return image

def preprocess_image(image):
  image = tf.image.resize(image, [224, 224])

  # If image has shape (H, W, 1), convert to RGB
  if image.shape[-1] == 1:
    image = tf.image.grayscale_to_rgb(image)

  image = image / 255.0
  return image

# 4. Create list of image paths and labels
image_dir = image_path
image_paths = []
labels = []

for fname in os.listdir(image_dir):

  if fname.endswith('.jpg'):

    img_id = os.path.splitext(fname)[0]
    label = metadata.get(img_id, {}).get('anomaly_class')

    if label in class_to_idx:

      image_paths.append(os.path.join(image_dir, fname))
      labels.append(class_to_idx[label])

# 5. Use train_test_split from sklearn
X_train, X_test, y_train, y_test = train_test_split(image_paths, labels, test_size=0.1, random_state=42, shuffle = True)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42, shuffle = True)

# setup augmentation
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.1),
    tf.keras.layers.RandomZoom(0.1),
    tf.keras.layers.RandomContrast(0.1)
])

# 6. Function to create TensorFlow dataset
def build_tf_dataset(paths, labels, batch_size=32, shuffle=True, training = False):

  dataset = tf.data.Dataset.from_tensor_slices((paths, labels))

  def load_img(path, label):

    image = tf.io.read_file(path)
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.adjust_contrast(image, 2.0)
    image = preprocess_image(image)

    # apply data augmentation to the training data
    if training:

      image = data_augmentation(image)

    return image, label

  dataset = dataset.map(load_img, num_parallel_calls=tf.data.AUTOTUNE)

  if shuffle:

    dataset = dataset.shuffle(buffer_size=1000)

  return dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)

# 7. Build datasets
train_ds = build_tf_dataset(X_train, y_train, training = True, shuffle = True)
val_ds = build_tf_dataset(X_val, y_val, shuffle=False, training = False)
test_ds = build_tf_dataset(X_test, y_test, shuffle=False, training = False)

# 8. Print sizes
print(f"Train samples: {len(X_train)}")
print(f"Validation samples: {len(X_val)}")
print(f"Test samples: {len(X_test)}")
# Out:
# Classes found: {'Cell': 0, 'Cell-Multi': 1, 'Cracking': 2, 'Diode': 3, 'Diode-Multi': 4, 'Hot-Spot': 5, 'Hot-Spot-Multi': 6, 'No-Anomaly': 7, 'Offline-Module': 8, 'Shadowing': 9, 'Soiling': 10, 'Vegetation': 11}
# Train samples: 14400
# Validation samples: 3600
# Test samples: 2000

# %% [markdown]
# lets view the training data as a numpy array

# %%
# view the training data numpy array form
image_batch, label_batch = next(iter(train_ds))

for image, label in zip(image_batch, label_batch):
  image = image.numpy()
  label = label.numpy()

print(f"Image: {image}")
print(f"Label: {label}")
# Out:
# Image: [[[0.92515117 0.92515117 0.92515117]
#   [0.9237195  0.9237195  0.9237195 ]
#   [0.92228615 0.92228615 0.92228615]
#   ...
#   [0.84140325 0.84140325 0.84140325]
#   [0.8437993  0.8437993  0.8437993 ]
#   [0.84744436 0.84744436 0.84744436]]
#
#  [[0.92255247 0.92255247 0.92255247]
#   [0.92112094 0.92112094 0.92112094]
#   [0.9196891  0.9196891  0.9196891 ]
#   ...
#   [0.8392746  0.8392746  0.8392746 ]
#   [0.8425922  0.8425922  0.8425922 ]
#   [0.84632564 0.84632564 0.84632564]]
#
#  [[0.9199538  0.9199538  0.9199538 ]
#   [0.91852224 0.91852224 0.91852224]
#   [0.91703874 0.91703874 0.91703874]
#   ...
#   [0.8380092  0.8380092  0.8380092 ]
#   [0.8417822  0.8417822  0.8417822 ]
#   [0.84559673 0.84559673 0.84559673]]
#
#  ...
#
#  [[0.90457606 0.90457606 0.90457606]
#   [0.8942726  0.8942726  0.8942726 ]
#   [0.8842196  0.8842196  0.8842196 ]
#   ...
#   [0.7803337  0.7803337  0.7803337 ]
#   [0.78226525 0.78226525 0.78226525]
#   [0.78382134 0.78382134 0.78382134]]
#
#  [[0.9052661  0.9052661  0.9052661 ]
#   [0.8949168  0.8949168  0.8949168 ]
#   [0.88508034 0.88508034 0.88508034]
#   ...
#   [0.78403145 0.78403145 0.78403145]
#   [0.78608495 0.78608495 0.78608495]
#   [0.78780323 0.78780323 0.78780323]]
#
#  [[0.9060179  0.9060179  0.9060179 ]
#   [0.8956401  0.8956401  0.8956401 ]
#   [0.8863919  0.8863919  0.8863919 ]
#   ...
#   [0.7880266  0.7880266  0.7880266 ]
#   [0.79023963 0.79023963 0.79023963]
#   [0.7921203  0.7921203  0.7921203 ]]]
# Label: 3

# %% [markdown]
# Now lets view the preprocessed thermal image in the training dataset.

# %%
import random
import matplotlib.pyplot as plt
import numpy as np
import cv2

# Reverse the class mapping to get index -> class name
idx_to_class = {v: k for k, v in class_to_idx.items()}

# Get a batch of images and labels from the training dataset
image_batch, label_batch = next(iter(train_ds))

# Print the shape of the image batch
print(f"Shape of full image batch: {image_batch.shape}")

# Choose a random subset of images to display (max 5)
num_images_to_display = min(10, len(image_batch))
random_indices = random.sample(range(len(image_batch)), num_images_to_display)

# Create a figure for plotting
plt.figure(figsize=(15, 15))

for i, index in enumerate(random_indices):
  image = image_batch[index].numpy()  # Convert image tensor to NumPy array
  label = label_batch[index].numpy()  # Convert label tensor to NumPy

  # Resize the image to 224x224 using OpenCV
  image_resized = cv2.resize(image, (224, 224))

  print(f"Shape of image {i}: {image.shape}")

  # Apply thermal effect using 'jet' colormap on the first channel
  thermal_image = np.clip(image * 255, 0, 255).astype(np.uint8)
  thermal_image = plt.cm.jet(thermal_image[..., 0])  # Apply colormap on 1st channel
  thermal_image = (thermal_image[..., :3] * 255).astype(np.uint8)  # Keep RGB only

  # Plot each image with label as text
  plt.subplot(5, 5, i + 1)
  plt.imshow(thermal_image)
  plt.title(f"Class: {idx_to_class[label]}")
  plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Shape of full image batch: (32, 224, 224, 3)
# Shape of image 0: (224, 224, 3)
# Shape of image 1: (224, 224, 3)
# Shape of image 2: (224, 224, 3)
# Shape of image 3: (224, 224, 3)
# Shape of image 4: (224, 224, 3)
# Shape of image 5: (224, 224, 3)
# Shape of image 6: (224, 224, 3)
# Shape of image 7: (224, 224, 3)
# Shape of image 8: (224, 224, 3)
# Shape of image 9: (224, 224, 3)

# %% [markdown]
# ## 4.0 Deep Learning Model

# %%
# import libraries
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import ResNet50V2

# define model architecture
def create_model(num_classes):
  '''using a pretrained model
  '''
  # setup random seed
  tf.random.set_seed(42)

  # load the model
  base_model = ResNet50V2(input_shape = (224, 224, 3), include_top = False, weights = 'imagenet')

  # freeze the base model layers
  base_model.trainable = False

  # create model architecture
  model = models.Sequential([
      base_model,
      layers.GlobalAveragePooling2D(),
      layers.Dense(512, activation = 'relu'),
      layers.Dropout(0.5),
      layers.Dense(num_classes, activation = 'softmax')
  ])

  # compile model
  model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = 0.001),
                loss = 'sparse_categorical_crossentropy',
                metrics = ['accuracy'])

  return model

# %%
# initiate the model
model = create_model(num_classes = len(class_to_idx))

# train the model
history = model.fit(train_ds, epochs = 10, validation_data = val_ds, verbose = 1)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Epoch 1/10
#   3/450 ━━━━━━━━━━━━━━━━━━━━ 39:12 5s/step - accuracy: 0.2639 - loss: 2.4383

# %% [markdown]
# Let's view the accuracy and loss curve

# %%
# view the model loss and accuracy curve
import matplotlib.pyplot as plt

# extract accuracy and loss
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

train_loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(train_acc) + 1)

# plot for accuracy
plt.figure(figsize = (10, 10))
plt.subplot(2, 1, 1)

plt.plot(epochs, train_acc, label = 'Train Accuracy')
plt.plot(epochs, val_acc, label = 'Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# plot loss
plt.subplot(2, 1, 2)
plt.plot(epochs, train_loss, label = 'Train loss')
plt.plot(epochs, val_loss, label = 'Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()

# %% [markdown]
# Time to fine-tune the ResNet50V2 model and improve the performance.

# %%
# setup epochs to be added with the final epoch
initial_epochs = 10
epoch_first_model = len(history.history['accuracy'])
total_epoch = initial_epochs + epoch_first_model

# Now fine-tune — extract the base model
base_model = model.layers[1]

# Unfreeze top N layers
unfreeze_layers = 50
for layer in base_model.layers[-unfreeze_layers:]:
  layer.trainable = True

# Recompile with low learning rate
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# train the model
history_fine_tune_model = model.fit(train_ds, validation_data = val_ds, epochs = total_epoch, initial_epoch = epoch_first_model, verbose = 1)

# %%
import matplotlib.pyplot as plt

# Extract accuracy and loss
train_acc += history_fine_tune_model.history['accuracy']
val_acc += history_fine_tune_model.history['val_accuracy']

train_loss += history_fine_tune_model.history['loss']
val_loss += history_fine_tune_model.history['val_loss']

epochs = range(1, len(train_acc) + 1)

# Epoch where fine-tuning started
fine_tuning_epoch = 4  # Change this to your specific fine-tuning epoch

# Plot for accuracy
plt.figure(figsize=(10, 10))

# Accuracy subplot
plt.subplot(2, 1, 1)
plt.plot(epochs, train_acc, label='Train Accuracy')
plt.plot(epochs, val_acc, label='Validation Accuracy')
plt.title('Training and Validation Accuracy after fine-tuning')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Add red dotted line and label for fine-tuning start
plt.axvline(x=fine_tuning_epoch, color='red', linestyle='--', label='Fine-Tuning Start')

# Loss subplot
plt.subplot(2, 1, 2)
plt.plot(epochs, train_loss, label='Train Loss')
plt.plot(epochs, val_loss, label='Validation Loss')
plt.title('Training and Validation Loss after fine-tuning')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Add red dotted line and label for fine-tuning start on loss curve
plt.axvline(x=fine_tuning_epoch, color='red', linestyle='--', label='Fine-Tuning Start')

plt.tight_layout()
